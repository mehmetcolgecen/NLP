# %%
import pandas as pd
import numpy as np
np.random.seed(42)

df = pd.read_csv('hsbc_twitter_DATA_not GENERAL.csv')
df.rename(columns={"NEW HUMAN CATEGORY\n 0-1000 /4000-4468 Michael\n 1000-2500 Mehmet \n 2500-4000 Aryamaan":"labels"}, inplace = True)
df.head()
# Out:
#                                                    tweet  \
# 0   2  @LondOgrad Hello Eugene, we do apologise for t...
# 1   8  @ncohen4 @CooperativeBank @HSBC @HSBCUKBusines...
# 2   9  @sharaola Good morning, sorry for your experie...
# 3  11        @Bounce_BackLoan Still not a peep from HSBC
# 4  15  @djm2481 @mgcmitchell @HSBC_UK Thanks for the ...
#
#   HUMAN CATEGORY\n ARYAMAAN:1-1000,4000-4468\n Michael-Mehmet:1000-4000  \
# 0                            CUSTOMER_SERVICE_ISSUES
# 1                                     BAD REPUTATION
# 2                            CUSTOMER_SERVICE_ISSUES
# 3                                              DELAY
# 4                          Customer Service Response
#
#                 SUB CATEGORY                   COMMENTS  \
# 0                        NaN       bad customer service
# 1                        NaN                        NaN
# 2                        NaN       bad customer service
# 3  Delay_in_bounce_back_loan  delay in bounce back loan
# 4                        NaN     customer service reply
#
#                       labels             SUB CATEGORY.1  \
# 0  Customer Service Response                        NaN
# 1                    General                        NaN
# 2  Customer Service Response                        NaN
# 3                      DELAY  Delay_in_bounce_back_loan
# 4  Customer Service Response                        NaN
#
#                   COMMENTS.1 human category (Tarun)  SUB CATEGORY.2  \
# 0     customer service reply                    NaN             NaN
# 1                        NaN                    NaN             NaN
# 2     customer service reply                    NaN             NaN
# 3  delay in bounce back loan                    NaN             NaN
# 4     customer service reply                    NaN             NaN
#
#    COMMENTS.2             NEW CATEGORY              keyword  \
# 0         NaN  customer_service issues                delay
# 1         NaN           Bad_reputation              unhappy
# 2         NaN  customer_service issues      customerservice
# 3         NaN    Delay_Bounceback_Loan  delay , no response
# 4         NaN                  General          any queries
#
#                          human - category  \
# 0                                   Delay
# 1               {'category': 'Reputation'
# 2  {'category': 'customer_service issues'
# 3         {'category': 'Bounce back loan'
# 4               {'category': 'Reputation'
#
#                                 human - Sub category  \
# 0                                     delay in calls
# 1                     subcategory': 'Bad reputation'
# 2                    subcategory': 'customerservice'
# 3            subcategory': 'Bounce back loan delays'
# 4  subcategory': 'General Response from Bank (tha...
#
#                                  Comment HUMAN CATGEORY_NEW(ARYA)  \
# 0                            Huge Queues  customer_service_issues
# 1  worst experience from customer – mess           BAD_REPUTATION
# 2             General response from bank                  General
# 3                               No reply    DELAY_BOUNCEBACK_LOAN
# 4             General response from bank                      NaN
#
#               location   COMMENTS (FROM PARIJAAT)  \
# 0           London, UK                        NaN
# 1    Plymouth, England                        NaN
# 2         Cairo, Egypt  General message from hsbc
# 3  Enschede, Nederland                      DELAY
# 4       United Kingdom                        NaN
#
#                           Category                               Sub-category
# 0             {'category': 'Delay'  subcategory': 'Delay in bounce back loan'
# 1        {'category': 'Reputation'            subcategory': 'Good reputation'
# 2        {'category': 'Reputation'            subcategory': 'Good reputation'
# 3  {'category': 'Bounce back loan'    subcategory': 'Bounce back loan delays'
# 4        {'category': 'Reputation'            subcategory': 'Good reputation'

# %%
# reducing General Data 1500
drop_indices = np.random.choice(df.loc[df["labels"]=="General"].index, 1500, replace=False)
df = df.drop(drop_indices)

# %%
df.labels.value_counts()
# Out:
# General                      769
# DELAY                        716
# Customer Service Response    653
# BAD REPUTATION               229
# CUSTOMER_SERVICE_ISSUES      227
# Customer Query               168
# GOOD REPUTATION              101
# COVID19                       50
# CHURN                         37
# ESG                            6
# Junk                           4
# Language                       2
# Name: labels, dtype: int64

# %%
df_clean = df.tweet
df_clean.shape
# Out:
# (2967,)

# %%
df_clean = df_clean.dropna()
df_clean.shape
# Out:
# (2967,)

# %%
df_clean
# Out:
# 0       @LondOgrad Hello Eugene, we do apologise for t...
# 2       @sharaola Good morning, sorry for your experie...
# 3             @Bounce_BackLoan Still not a peep from HSBC
# 4       @djm2481 @mgcmitchell @HSBC_UK Thanks for the ...
# 5       @Bounce_BackLoan any evidence of anyone gettin...
#                               ...
# 4462    @demosisto why should HSBC show their support?...
# 4463    @BritishBBank @Bounce_BackLoan @Metro_Bank I w...
# 4464    @WWIIadvertising Hi David. Sorry somethings up...
# 4465    @HSBC thank you I just called in on the phone ...
# 4466    @shezRommy @Bounce_BackLoan Probably be quicke...
# Name: tweet, Length: 2967, dtype: object

# %%
list_data = df_clean.to_list()
list_data = [str(sent) for sent in list_data]

# %%
from sentence_transformers import SentenceTransformer

# %%
# distilbert-base-nli-mean-tokens
# paraphrase-distilroberta-base-v1

# %%
model=SentenceTransformer('paraphrase-distilroberta-base-v1')
embeddings = model.encode(list_data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/93 [00:00<?, ?it/s]

# %%
embeddings.shape
# Out:
# (2967, 768)

# %%
import umap

# %%
three_dim_embedding = umap.UMAP(n_components=3).fit_transform(embeddings)
#n_neighbors=10, min_dist=0.0,

# %%
three_dim_embedding
# Out:
# array([[-0.21750711,  5.1691723 ,  1.8341097 ],
#        [ 0.85636634,  5.263206  ,  2.3382912 ],
#        [-0.97281075,  0.04238867, -0.7292106 ],
#        ...,
#        [ 0.37677526,  4.714656  ,  2.492212  ],
#        [-0.8124863 ,  2.9303033 ,  1.8894824 ],
#        [-2.4499943 ,  1.1132046 , -0.01254607]], dtype=float32)

# %%
import hdbscan

# %%
def cluster_results(min_samples1=10,min_samples2=10,min_samples3=10):
    global cluster1,cluster2,cluster3
    cluster1 = hdbscan.HDBSCAN(min_samples = min_samples1,).fit_predict(three_dim_embedding)

    cluster2 = hdbscan.HDBSCAN(min_samples = min_samples2,
                               cluster_selection_epsilon = 0.5).fit_predict(three_dim_embedding)

    cluster3 = hdbscan.HDBSCAN(min_samples = min_samples3,
                               min_cluster_size=10,
                               cluster_selection_epsilon = 0.5,
                               metric = 'euclidean',
                               cluster_selection_method = "eom").fit_predict(three_dim_embedding)

    clusters = cluster1,cluster2,cluster3

    for cluster in clusters:
        unique, counts = np.unique(cluster, return_counts=True)
        print(dict(zip(unique, counts)))

# %%
cluster_results(min_samples1=15,min_samples2=15,min_samples3=15)
# Out:
# {-1: 304, 0: 23, 1: 19, 2: 16, 3: 27, 4: 62, 5: 2253, 6: 38, 7: 71, 8: 115, 9: 29, 10: 10}
# {-1: 82, 0: 23, 1: 547, 2: 62, 3: 2253}
# {-1: 82, 0: 23, 1: 547, 2: 62, 3: 2253}

# %%
cluster = cluster1

import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style='white', rc={'figure.figsize':(10,8)})

two_dim_embedding = umap.UMAP(n_components=2).fit_transform(embeddings)


clustered = (cluster >= 0)
plt.scatter(two_dim_embedding[~clustered, 0],
            two_dim_embedding[~clustered, 1],
            c=(0.5,0.5,0.5),
            # s=1,
            alpha=0.5
            )
plt.scatter(two_dim_embedding[clustered, 0],
            two_dim_embedding[clustered, 1],
            c=cluster[clustered],
            # s=1,
            cmap='Spectral');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
docs = pd.DataFrame(df_clean)
docs["cluster"] = cluster
docs
# Out:
#                                                   tweet  cluster
# 0     @LondOgrad Hello Eugene, we do apologise for t...       -1
# 2     @sharaola Good morning, sorry for your experie...        8
# 3           @Bounce_BackLoan Still not a peep from HSBC        5
# 4     @djm2481 @mgcmitchell @HSBC_UK Thanks for the ...       -1
# 5     @Bounce_BackLoan any evidence of anyone gettin...        5
# ...                                                 ...      ...
# 4462  @demosisto why should HSBC show their support?...        5
# 4463  @BritishBBank @Bounce_BackLoan @Metro_Bank I w...        5
# 4464  @WWIIadvertising Hi David. Sorry somethings up...        8
# 4465  @HSBC thank you I just called in on the phone ...        5
# 4466  @shezRommy @Bounce_BackLoan Probably be quicke...        5
#
# [2967 rows x 2 columns]

# %%
labeled_docs_all = docs.groupby(["cluster"], as_index=False).agg({"tweet": " ".join})

# %%
labeled_docs_all
# Out:
#     cluster                                              tweet
# 0        -1  @LondOgrad Hello Eugene, we do apologise for t...
# 1         0  @craig_removals @Bounce_BackLoan @ting_tong22 ...
# 2         1  @TroullosAndrew Hi Andrew, we are receiving ex...
# 3         2  @harshildave87 Thanks for sharing! This is not...
# 4         3  @ptaylo Hi Phil. This isn't a genuine text fro...
# 5         4  You can hear from some of the hottest brands a...
# 6         5  @Bounce_BackLoan Still not a peep from HSBC @B...
# 7         6  Good morning, I am Nanis and I'll be happy to ...
# 8         7  @harshcasm Hello Harish, thank you for writing...
# 9         8  @sharaola Good morning, sorry for your experie...
# 10        9  @IamCK12 Hello Mr.Diwan, thank you for writing...
# 11       10  @LeonHook Unfortunately over this channel we a...

# %%
import re

def remove_unicode(text):

    try:
        text = text.encode("latin_1").decode("raw_unicode_escape").encode('utf-16', 'surrogatepass').decode('utf-16')
    except:
        text = text
        
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
        "]+", re.UNICODE)
    
    text = re.sub(emoji_pattern, '', text)
    text = ''.join(text.split('\\n')) # to remove uncompiled \n
    text = re.sub('\n', '', text)     # to remove compiled \n

    return text

# %%
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
# tokens_without_sw=[t for t in list_data2 if t not in stop_words]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def clean_data(text, small_word_lmt=3, extra_words=["hsbc","ðÿœˆ","bank"], stop_words = stop_words):
    
    text = remove_unicode(text)
    list_data2=[]
    sentence=text.lower().split(' ')
    for word in sentence:
        if not (word.startswith('@') | word.startswith('#') | word.startswith('http')) \
           and len(word) > small_word_lmt \
           and not word.isnumeric() \
           and word not in extra_words \
           and word not in stop_words \
           and word.isalpha() :
            list_data2.append(word)

    return " ".join(list_data2)

# %%
labeled_docs = labeled_docs_all
labeled_docs.tweet = labeled_docs_all.tweet.apply(clean_data)

# %%
labeled_docs
# Out:
#     cluster                                              tweet
# 0        -1  hello apologise delay current lines huge check...
# 1         0  personal barclays want account face next barcl...
# 2         1  receiving extremely high volumes requests busi...
# 3         2  thanks please click link report phishing sharo...
# 4         3  genuine text thank report sending hello thanks...
# 5         4  hear hottest brands dial speakers coca mark cu...
# 6         5  still peep evidence anyone getting think paid ...
# 7         6  good nanis happy answer banking questions quer...
# 8         7  hello thank writing back online transactions c...
# 9         8  good sorry please send contact details along n...
# 10        9  hello thank writing order assist would need re...
# 11       10  unfortunately channel limited data call agent ...

# %%
del labeled_docs_try

# %%
 pd.set_option('display.max_columns', 50)
# pd.set_option('display.max_rows', None)

# %%
labeled_docs_try =pd.DataFrame(df_clean)
labeled_docs_try["labels"] = df.labels
labeled_docs_try["cluster"] = docs.cluster
labeled_docs_try.head(50)
pd.crosstab(labeled_docs_try.labels, labeled_docs_try.cluster)
# Out:
# cluster                    -1    0    1    2    3    4    5    6    7    8   \
# labels
# BAD REPUTATION               1    3    0    0    0    1  224    0    0    0
# CHURN                        0    0    0    0    0    0   37    0    0    0
# COVID19                      8    0    0    0    0    0   42    0    0    0
# CUSTOMER_SERVICE_ISSUES      1    0    0    0    0    0  225    0    1    0
# Customer Query               3    0    0    0    0    0  165    0    0    0
# Customer Service Response  252    0   18   15   27    0   82   38   69  113
# DELAY                        5    0    0    0    0    0  711    0    0    0
# ESG                          0    0    0    0    0    0    6    0    0    0
# GOOD REPUTATION              3   18    0    0    0    0   80    0    0    0
# General                     31    2    1    1    0   61  671    0    1    1
# Junk                         0    0    0    0    0    0    3    0    0    1
# Language                     0    0    0    0    0    0    2    0    0    0
#
# cluster                     9    10
# labels
# BAD REPUTATION               0    0
# CHURN                        0    0
# COVID19                      0    0
# CUSTOMER_SERVICE_ISSUES      0    0
# Customer Query               0    0
# Customer Service Response   29   10
# DELAY                        0    0
# ESG                          0    0
# GOOD REPUTATION              0    0
# General                      0    0
# Junk                         0    0
# Language                     0    0

# %%
labeled_docs_try["labels"].value_counts()
# Out:
# General                      769
# DELAY                        716
# Customer Service Response    653
# BAD REPUTATION               229
# CUSTOMER_SERVICE_ISSUES      227
# Customer Query               168
# GOOD REPUTATION              101
# COVID19                       50
# CHURN                         37
# ESG                            6
# Junk                           4
# Language                       2
# Name: labels, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
def tfidfmatrix(data, vectorizer):
    terms = vectorizer.fit_transform(data)
    return pd.DataFrame(terms.toarray(), columns = vectorizer.get_feature_names())

tfidf_vec = TfidfVectorizer()

# %%
tfidf_mat = tfidfmatrix(labeled_docs.tweet, tfidf_vec)

# %%
tfidf_mat
# Out:
#     abandoned   abigail   ability      able    aboard   abrindo    abroad  \
# 0    0.000000  0.008407  0.000000  0.129778  0.000000  0.000000  0.000000
# 1    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5    0.000000  0.000000  0.000000  0.000000  0.000000  0.050322  0.000000
# 6    0.001329  0.000000  0.003988  0.040224  0.001329  0.000000  0.001329
# 7    0.000000  0.000000  0.000000  0.044728  0.000000  0.000000  0.000000
# 8    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9    0.000000  0.000000  0.000000  0.027505  0.000000  0.000000  0.000000
# 10   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11   0.000000  0.000000  0.000000  0.163706  0.000000  0.000000  0.000000
#
#         abse  absolute  absolutely     abtak     abuse  academic  accelerate  \
# 0   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000    0.000000
# 1   0.000000  0.294747    0.016375  0.000000  0.000000  0.000000    0.000000
# 2   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000    0.000000
# 3   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000    0.000000
# 4   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000    0.000000
# 5   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000    0.000000
# 6   0.001329  0.013701    0.027403  0.001329  0.002659  0.001329    0.005318
# 7   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000    0.000000
# 8   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000    0.000000
# 9   0.000000  0.000000    0.000000  0.000000  0.000000  0.000000    0.000000
# 10  0.000000  0.000000    0.000000  0.000000  0.000000  0.000000    0.000000
# 11  0.000000  0.000000    0.000000  0.000000  0.000000  0.000000    0.000000
#
#     accelerating    accept  acceptable  acceptance  accepted  accepting  \
# 0       0.000000  0.006378    0.000000    0.000000  0.000000   0.000000
# 1       0.000000  0.000000    0.000000    0.000000  0.000000   0.000000
# 2       0.000000  0.000000    0.000000    0.000000  0.000000   0.000000
# 3       0.000000  0.000000    0.000000    0.000000  0.000000   0.000000
# 4       0.000000  0.000000    0.000000    0.000000  0.000000   0.000000
# 5       0.000000  0.000000    0.000000    0.000000  0.000000   0.000000
# 6       0.001329  0.006052    0.001329    0.003988  0.015954   0.006647
# 7       0.000000  0.000000    0.000000    0.000000  0.000000   0.000000
# 8       0.000000  0.032786    0.000000    0.000000  0.000000   0.000000
# 9       0.000000  0.000000    0.000000    0.000000  0.000000   0.000000
# 10      0.000000  0.000000    0.000000    0.000000  0.000000   0.000000
# 11      0.000000  0.000000    0.000000    0.000000  0.000000   0.000000
#
#        acces  accesible    access  accessible  accident  ...     wrong  \
# 0   0.000000   0.000000  0.031891    0.000000  0.000000  ...  0.000000
# 1   0.000000   0.000000  0.000000    0.000000  0.000000  ...  0.000000
# 2   0.000000   0.000000  0.000000    0.000000  0.000000  ...  0.000000
# 3   0.000000   0.000000  0.000000    0.000000  0.000000  ...  0.000000
# 4   0.000000   0.000000  0.175060    0.000000  0.000000  ...  0.000000
# 5   0.000000   0.000000  0.000000    0.000000  0.000000  ...  0.000000
# 6   0.001329   0.001329  0.034293    0.002659  0.001329  ...  0.025119
# 7   0.000000   0.000000  0.000000    0.000000  0.000000  ...  0.000000
# 8   0.000000   0.000000  0.000000    0.000000  0.000000  ...  0.000000
# 9   0.000000   0.000000  0.000000    0.000000  0.000000  ...  0.009564
# 10  0.000000   0.000000  0.000000    0.000000  0.000000  ...  0.000000
# 11  0.000000   0.000000  0.000000    0.000000  0.000000  ...  0.000000
#
#        wrote  xancelled  xxxxxxxxxxx     yahoo      yday      yeah      year  \
# 0   0.000000   0.000000     0.000000  0.000000  0.000000  0.000000  0.007220
# 1   0.000000   0.000000     0.000000  0.000000  0.000000  0.000000  0.000000
# 2   0.000000   0.000000     0.000000  0.000000  0.000000  0.000000  0.000000
# 3   0.000000   0.000000     0.000000  0.000000  0.000000  0.000000  0.000000
# 4   0.000000   0.000000     0.000000  0.000000  0.000000  0.000000  0.000000
# 5   0.000000   0.000000     0.000000  0.000000  0.000000  0.000000  0.000000
# 6   0.003988   0.001329     0.001329  0.001329  0.001329  0.006647  0.013701
# 7   0.000000   0.000000     0.000000  0.000000  0.000000  0.000000  0.000000
# 8   0.000000   0.000000     0.000000  0.000000  0.000000  0.000000  0.000000
# 9   0.000000   0.000000     0.000000  0.000000  0.000000  0.000000  0.000000
# 10  0.000000   0.000000     0.000000  0.000000  0.000000  0.000000  0.000000
# 11  0.000000   0.000000     0.000000  0.000000  0.000000  0.000000  0.000000
#
#       yearly     years   yelling  yesterday     yield    yippee      york  \
# 0   0.000000  0.012756  0.000000   0.000000  0.000000  0.000000  0.000000
# 1   0.000000  0.245902  0.000000   0.016375  0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 6   0.001329  0.034293  0.001329   0.037679  0.001329  0.001329  0.005318
# 7   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 8   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000   0.000000  0.000000  0.000000  0.000000
#
#     yorkshire     young     youre   youtube     youve      yung    zejtun  \
# 0    0.000000  0.000000  0.000000  0.007220  0.000000  0.000000  0.000000
# 1    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 2    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 3    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 4    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 6    0.003988  0.001329  0.001329  0.001142  0.001329  0.001329  0.001329
# 7    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 8    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 9    0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 10   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 11   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#         zero    zeroed      ziad
# 0   0.000000  0.000000  0.000000
# 1   0.000000  0.000000  0.000000
# 2   0.000000  0.000000  0.000000
# 3   0.000000  0.000000  0.000000
# 4   0.000000  0.000000  0.000000
# 5   0.000000  0.000000  0.000000
# 6   0.009306  0.001329  0.000000
# 7   0.000000  0.000000  0.108659
# 8   0.000000  0.000000  0.000000
# 9   0.000000  0.000000  0.000000
# 10  0.000000  0.000000  0.000000
# 11  0.000000  0.000000  0.000000
#
# [12 rows x 4379 columns]

# %%
top_n = 15
most_common = pd.DataFrame({n: tfidf_mat.T[col].nlargest(top_n).index.tolist() 
                        for n, col in enumerate(tfidf_mat.T)}).T

# %%
most_common.index = np.unique(cluster)
most_common
# Out:
#                0         1          2          3         4          5   \
# -1          thank     hello      sorry     thanks   writing       team
#  0          worst  absolute     feeder     minute  business  connected
#  1   applications   quickly  thousands     bounce  possible    working
#  2     screenshot    thanks       send      click      link     please
#  3           text      scam    forward       send  attached   messages
#  4           join      coca    content      cuban   hottest  institute
#  5        applied     still    account     feeder   waiting       back
#  6        morning     happy    queries       good    assist    banking
#  7           team    kindly      hello  concerned      send     hsbcsm
#  8           full      name     please      sorry      post       link
#  9         assist     refer      phone    request  services      order
#  10          call      chat    limited       live    please       able
#
#            6           7          8         9         10           11  \
# -1     please        call     number      able     happy      details
#  0     within       every      years    bounce    regret     customer
#  1   business    received  customers      back     funds       coming
#  2     report       hello      right  phishing      wish        crock
#  3      links     letting      thank  phishing    delete   screenshot
#  4      lined        mark   shanghai   speaker  speakers       brands
#  5   business      bounce       loan     weeks     money  application
#  6   tomorrow       great      tweet  thursday      hope         help
#  7      fetch  registered      thank   checked   details       mobile
#  8       look        code       send  postcode      help        thank
#  9    banking        call       need   writing     would        thank
#  10     agent        data    banking      help   channel     mortgage
#
#             12           13       14
# -1        link         back   kindly
#  0     account   experience     call
#  1     applied         make    loans
#  2      sharon  immediately     knew
#  3      access        email     stay
#  4        dial    marketing     line
#  5       since       people     told
#  6        back      weekend     ayat
#  7      number      request  writing
#  8       check        using   thanks
#  9   regarding         team    hello
#  10     option    responses     talk
