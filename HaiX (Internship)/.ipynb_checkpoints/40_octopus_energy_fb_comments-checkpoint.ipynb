# %%
import re
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import umap
import nltk
import spacy
import string
import hdbscan

import preprocessor as p

import matplotlib.pyplot as plt
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')
import seaborn as sns
sns.set(style='white', rc={'figure.figsize':(10,8)})

np.random.seed(42)
# %config Completer.use_jedi = False
pd.set_option('display.max_columns', 30)
# pd.set_option('display.max_rows', 100)

nlp = spacy.load("en_core_web_sm")

# %%
df = pd.read_csv('octopus_energy_fb_comments.csv')
df.rename(columns={"fb_comment":"comments"},inplace=True)
df.head()
# Out:
#    Unnamed: 0                                           comments
# 0           0                              Congratulations Laura
# 1           1  Rang u as my smart meter ain't working on scre...
# 2           2  I just applied switched to Octopus , but can I...
# 3           3        What do I need to do to get smart metres...
# 4           4                                Could of phoned me

# %%
df.comments.replace("\n" , " ", regex=True, inplace = True)
df.comments=df.comments.apply(lambda x:p.clean(str(x)))

# %%
df.replace('nan', np.nan, inplace = True)
df.replace('', np.nan, inplace = True)
df.replace('do', np.nan, inplace = True)
df = df.dropna()

# %%
list_data = df.comments.unique().tolist()

# %%
len(list_data)
# Out:
# 736

# %%
from sentence_transformers import SentenceTransformer

# %%
# distilbert-base-nli-mean-tokens
# paraphrase-distilroberta-base-v1
# roberta-large-nli-stsb-mean-tokens
#allenai-specter

# %%
model=SentenceTransformer('xlm-r-distilroberta-base-paraphrase-v1')
embeddings = model.encode(list_data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/23 [00:00<?, ?it/s]

# %%
best_model = umap.UMAP(n_components=5).fit_transform(embeddings)

#n_neighbors=10, min_dist=0.0,

# %%
#inertia

kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(best_model)
                for k in range(1, 10)]
inertias = [model.inertia_ for model in kmeans_per_k]

plt.plot(range(1, 10), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.show()

# %%
# from nltk.cluster import KMeansClusterer,euclidean_distance
# clusterer =KMeansClusterer(6,euclidean_distance)
# cluster=np.array(clusterer.cluster(best_model,True))

# %%
# cluster = KMeans(n_clusters=1, init="k-means++").fit_predict(best_model)

# %%
cluster = hdbscan.HDBSCAN().fit_predict(best_model)

# %%
def plot(cluster = cluster):    

    clustered = (cluster >= 0)
    reduced_dim = umap.UMAP(n_components=2).fit_transform(embeddings)



    unique, counts = np.unique(cluster, return_counts=True)
    print(dict(zip(unique, counts)))

    plt.scatter(reduced_dim[~clustered, 0],
                reduced_dim[~clustered, 1],
                c=(0.5,0.5,0.5),
                # s=1,
                alpha=0.5
                )
    plt.scatter(reduced_dim[clustered, 0],
                reduced_dim[clustered, 1],
                c=cluster[clustered],
                # s=1,
                cmap='Accent')
    plt.show()

# %%
plot()
# Out:
# {-1: 72, 0: 25, 1: 34, 2: 11, 3: 21, 4: 428, 5: 99, 6: 46}

# %%
len(cluster)
# Out:
# 736

# %%
def word_root(text):
    list_data3=[]
    doc = nlp(text)
    for token in doc:
        if token.text.isalpha() and len(token.text)>2:
            lemma = token.lemma_
            list_data3.append(lemma)
        else:pass
    return " ".join(list_data3)

# %%
docs = pd.DataFrame(list_data,columns=["comments"])
docs["cluster"] = cluster
labeled_docs = docs.groupby(["cluster"], as_index=False).agg({"comments": " ".join})
labeled_docs.comments = labeled_docs.comments.apply(lambda x: word_root(str(x).lower()))  
labeled_docs
# Out:
#    cluster                                           comments
# 0       -1  congratulation laura great company with a soci...
# 1        0  you know when they say you couldn t make it up...
# 2        1  talk about eagle eye on your consumption enter...
# 3        2  clever stuff just need an electric car for k l...
# 4        3  well do awesome company good energy company st...
# 5        4  ring u as my smart meter ai work on screen for...
# 6        5  lisa maureen jenkin see it on the tonight prog...
# 7        6  fantastic news well do xxx amazing my next one...

# %%
from keybert import KeyBERT
array_text = labeled_docs.comments.tolist()
kw_extractor = KeyBERT(model=model)
bigram=[]
for j in range(len(array_text)-1):
    keywords = kw_extractor.extract_keywords(array_text[j+1],top_n=10,keyphrase_ngram_range=(2, 2))
    print(f'\033[1m   Bigram Cluster {j+1}: \033[0m' )
    print([word for word in keywords])
    bigram.append([word[0] for word in keywords])
# Out:
#    Bigram Cluster 1:
# [('enter quiz', 0.5044), ('thankyou quiz', 0.5037), ('awesome quiz', 0.4947), ('scramble quiz', 0.4851), ('great quiz', 0.4759), ('good quiz', 0.4726), ('cos prize', 0.4709), ('answer prize', 0.4663), ('thank winner', 0.4557), ('excellent winner', 0.4539)]
#    Bigram Cluster 2:
# [('apple cake', 0.6136), ('cake apple', 0.5813), ('chocolate cake', 0.5653), ('apple cookie', 0.5577), ('pie cupcake', 0.5425), ('apple pie', 0.5403), ('apple chocolate', 0.523), ('use cake', 0.511), ('pie apple', 0.5044), ('cake make', 0.4971)]
#    Bigram Cluster 3:
# [('electric car', 0.4987), ('obvious electric', 0.4422), ('love electric', 0.4391), ('need electric', 0.4378), ('idea electric', 0.4177), ('electrician prefer', 0.4133), ('awesome car', 0.4123), ('car expensive', 0.4121), ('car just', 0.3923), ('afford electric', 0.3868)]
#    Bigram Cluster 4:
# [('great company', 0.654), ('good company', 0.6457), ('awesome company', 0.6249), ('company great', 0.6247), ('company good', 0.6015), ('company deserve', 0.5677), ('brilliant company', 0.5602), ('fantastic company', 0.5578), ('great service', 0.5466), ('company prosper', 0.5175)]
#    Bigram Cluster 5:
# [('meter octopus', 0.4399), ('fix octopus', 0.4358), ('phone octopus', 0.4267), ('provider octopus', 0.4255), ('smart meter', 0.4244), ('install meter', 0.4233), ('electric octopus', 0.4162), ('customer octopi', 0.4141), ('customer octopus', 0.414), ('thank octopus', 0.412)]
#    Bigram Cluster 6:
# [('tonight programme', 0.5016), ('lisa maureen', 0.4702), ('jenkin tonight', 0.4431), ('programme night', 0.4424), ('xx liz', 0.4016), ('prentice william', 0.3963), ('jacqueline stevenson', 0.3879), ('channe russell', 0.3873), ('clinton jamie', 0.3846), ('lisa middleton', 0.3807)]
#    Bigram Cluster 7:
# [('news great', 0.5513), ('great post', 0.5328), ('great news', 0.5227), ('excellent news', 0.5226), ('bird excellent', 0.5201), ('fun fantastic', 0.5122), ('news good', 0.5121), ('xxx amazing', 0.5002), ('ohm great', 0.4833), ('thank enjoy', 0.4826)]

# %%
unigram=[]
for j in range(len(array_text)-1):
    keywords = kw_extractor.extract_keywords(array_text[j+1],top_n=10,keyphrase_ngram_range=(1, 1))
    print(f'\033[1m   Unigram Cluster {j+1}: \033[0m' )
    print([word for word in keywords])
    unigram.append([word[0] for word in keywords])
# Out:
#    Unigram Cluster 1:
# [('winner', 0.3934), ('prize', 0.3882), ('award', 0.3514), ('quiz', 0.3495), ('competition', 0.3105), ('competetive', 0.3081), ('win', 0.3019), ('lucky', 0.2917), ('thankyou', 0.2878), ('excellent', 0.2713)]
#    Unigram Cluster 2:
# [('cake', 0.4303), ('cupcake', 0.4017), ('apple', 0.3681), ('chocolate', 0.3506), ('cookie', 0.3347), ('cranberry', 0.3209), ('pastry', 0.3179), ('octocake', 0.3133), ('enjoy', 0.2458), ('consumption', 0.2289)]
#    Unigram Cluster 3:
# [('battery', 0.3426), ('recyclable', 0.3202), ('electric', 0.318), ('electrician', 0.2977), ('car', 0.2867), ('expensive', 0.2715), ('obvious', 0.2508), ('chemical', 0.2448), ('renewable', 0.2348), ('essence', 0.2311)]
#    Unigram Cluster 4:
# [('company', 0.3844), ('good', 0.3374), ('awesome', 0.334), ('brilliant', 0.3319), ('incompetence', 0.331), ('deserve', 0.3264), ('great', 0.3092), ('fantastic', 0.2949), ('service', 0.2868), ('terrible', 0.2774)]
#    Unigram Cluster 5:
# [('octopusenergycustomer', 0.354), ('octopus', 0.3513), ('octopu', 0.3164), ('octopi', 0.3125), ('octopusenergy', 0.3046), ('octopuse', 0.3035), ('meter', 0.2976), ('octopusy', 0.2867), ('octopussy', 0.2854), ('octoturny', 0.2702)]
#    Unigram Cluster 6:
# [('programme', 0.3771), ('tonight', 0.3679), ('liz', 0.361), ('lisa', 0.3557), ('jess', 0.3502), ('maureen', 0.3457), ('garnett', 0.3194), ('quiz', 0.3146), ('prentice', 0.3091), ('lass', 0.3072)]
#    Unigram Cluster 7:
# [('excellent', 0.5156), ('amazing', 0.45), ('fantastic', 0.4342), ('enjoy', 0.4062), ('great', 0.4052), ('good', 0.3977), ('beautiful', 0.3656), ('interesting', 0.3627), ('nice', 0.3596), ('wow', 0.3479)]

# %%
for i in range(len(array_text)-1):
    clusterer=[]
    bigramer=[]
    print(f'\033[1m   Cluster {i+1}: \033[0m')
    [clusterer.append(j) for j in unigram[i]]
    clusterer.append(bigram[i][0])
    
    for word in bigram[i][0].split(" "):
        if word not in bigramer:
            bigramer.append(word)
    
    for each in bigram[i]:
        first,second=each.split(" ")
        if first != second and not(first in bigramer and second in bigramer):
            clusterer.append(each)
            if bigramer.append(first): first not in bigramer
            if bigramer.append(second): second not in bigramer
    print(clusterer)
# Out:
#    Cluster 1:
# ['winner', 'prize', 'award', 'quiz', 'competition', 'competetive', 'win', 'lucky', 'thankyou', 'excellent', 'enter quiz', 'thankyou quiz', 'awesome quiz', 'scramble quiz', 'great quiz', 'good quiz', 'cos prize', 'answer prize', 'thank winner', 'excellent winner']
#    Cluster 2:
# ['cake', 'cupcake', 'apple', 'chocolate', 'cookie', 'cranberry', 'pastry', 'octocake', 'enjoy', 'consumption', 'apple cake', 'chocolate cake', 'apple cookie', 'pie cupcake', 'use cake', 'cake make']
#    Cluster 3:
# ['battery', 'recyclable', 'electric', 'electrician', 'car', 'expensive', 'obvious', 'chemical', 'renewable', 'essence', 'electric car', 'obvious electric', 'love electric', 'need electric', 'idea electric', 'electrician prefer', 'awesome car', 'car expensive', 'car just', 'afford electric']
#    Cluster 4:
# ['company', 'good', 'awesome', 'brilliant', 'incompetence', 'deserve', 'great', 'fantastic', 'service', 'terrible', 'great company', 'good company', 'awesome company', 'company deserve', 'brilliant company', 'fantastic company', 'great service', 'company prosper']
#    Cluster 5:
# ['octopusenergycustomer', 'octopus', 'octopu', 'octopi', 'octopusenergy', 'octopuse', 'meter', 'octopusy', 'octopussy', 'octoturny', 'meter octopus', 'fix octopus', 'phone octopus', 'provider octopus', 'smart meter', 'install meter', 'electric octopus', 'customer octopi', 'thank octopus']
#    Cluster 6:
# ['programme', 'tonight', 'liz', 'lisa', 'jess', 'maureen', 'garnett', 'quiz', 'prentice', 'lass', 'tonight programme', 'lisa maureen', 'jenkin tonight', 'programme night', 'xx liz', 'prentice william', 'jacqueline stevenson', 'channe russell', 'clinton jamie', 'lisa middleton']
#    Cluster 7:
# ['excellent', 'amazing', 'fantastic', 'enjoy', 'great', 'good', 'beautiful', 'interesting', 'nice', 'wow', 'news great', 'great post', 'excellent news', 'bird excellent', 'fun fantastic', 'news good', 'xxx amazing', 'ohm great', 'thank enjoy']

# %%
labeled_docs.comments[7]
# Out:
# 'fantastic news well do xxx amazing my next one sound like a bit of a hawkward situation ha ha brilliant what a beautiful bird excellent news it be a great post thank you we enjoy it be a bit of fun and something different to do yes be there ca wait yes please I m in sound fun fantastic news and well deserve well do winner I actually ca nt believe this excited finger cross congratulation it a nice idea and a be a great base for this amazing it the way to go do have always want one love it done all do ca nt bake as ca nt afford to with these price this be our effort order this be amazing not equal opportunity then lol great story but to have that clown visit be embarrassing joy jame you probably be excellent news I ve spend time over there some great techie geek who will really embrace the concept great news good luck guy this be amazing news well do good luck amazing news door to door sell during a pandemic be irresponsible I m sorry but I think that s shocking ohm y what a great idea love some but ca afford have a look at I love bellerin wow wow this be soo interesting'

# %%
labeled_docs.comments[4]
# Out:
