# %%
import pandas as pd
import numpy as np
np.random.seed(42)
# %config Completer.use_jedi = False
pd.set_option('display.max_columns', 30)
# pd.set_option('display.max_rows', None)

# %%
df = pd.read_csv('hsbc_twitter_DATA_not GENERAL.csv')
df.rename(columns={"NEW HUMAN CATEGORY\n 0-1000 /4000-4468 Michael\n 1000-2500 Mehmet \n 2500-4000 Aryamaan":"labels"}, inplace = True)
df.head()
# Out:
#                                                    tweet  \
# 0   2  @LondOgrad Hello Eugene, we do apologise for t...
# 1   8  @ncohen4 @CooperativeBank @HSBC @HSBCUKBusines...
# 2   9  @sharaola Good morning, sorry for your experie...
# 3  11        @Bounce_BackLoan Still not a peep from HSBC
# 4  15  @djm2481 @mgcmitchell @HSBC_UK Thanks for the ...
#
#   HUMAN CATEGORY\n ARYAMAAN:1-1000,4000-4468\n Michael-Mehmet:1000-4000  \
# 0                            CUSTOMER_SERVICE_ISSUES
# 1                                     BAD REPUTATION
# 2                            CUSTOMER_SERVICE_ISSUES
# 3                                              DELAY
# 4                          Customer Service Response
#
#                 SUB CATEGORY                   COMMENTS  \
# 0                        NaN       bad customer service
# 1                        NaN                        NaN
# 2                        NaN       bad customer service
# ...

# %%
# reducing General Data 1500
drop_indices = np.random.choice(df.loc[df["labels"]=="General"].index, 1500, replace=False)
df = df.drop(drop_indices)

# %%
df.labels.value_counts()
# Out:
# General                      769
# DELAY                        716
# Customer Service Response    653
# BAD REPUTATION               229
# CUSTOMER_SERVICE_ISSUES      227
# Customer Query               168
# GOOD REPUTATION              101
# COVID19                       50
# CHURN                         37
# ESG                            6
# Junk                           4
# Language                       2
# Name: labels, dtype: int64

# %%
df.tweet = df.tweet.str.lower()

# %%
df.tweet.replace(r"\S*covid\S*", "covid", regex=True, inplace = True)
df.tweet.replace(r"\S*corona\S*" , "covid", regex=True, inplace = True)
df.tweet.replace(r"\S*bbl\S*" , "", regex=True, inplace = True)
df.tweet.replace(r"\S*bounce\S*" , "", regex=True, inplace = True)
df.tweet.replace(r"\S*bounce_\S*" , "", regex=True, inplace = True)
df.tweet.replace(r"\S*bounce back loan\S*" , "", regex=True, inplace = True)
df.tweet.replace(r"\S*thank\S*" , "thank", regex=True, inplace = True)
df.tweet.replace(r"\S*thx\S*" , "thank", regex=True, inplace = True)
df.tweet.replace(r"hi" , "hello", regex=True, inplace = True)
df.tweet.replace(r"\S*hsbc\S*" , "", regex=True, inplace = True)
df.tweet.replace(r"[^a-zA-Z0-9 .]+" , "", regex=True, inplace = True)

df.tweet.replace(r"\S*delay\S" , "delay "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*wait\S" , "wait "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*longer time\S*" , "longer time "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*too long\S*" , "too long "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*still waiting\S*" , "still waiting "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*heard nothing\S*" , "heard nothing "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*still nothing\S*" , "still nothing "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*any news\S*" , "any news "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*awful\S*" , "awful "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*disappointed\S*" , "disappointed "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*gave up\S*" , "gave up "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*worse\S*" , "worse "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*worst\S*" , "worst "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*unhappy\S*" , "unhappy "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*sucks\S*" , "sucks "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*unbelievable\S*" , "unbelievable "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*frustrated\S*" , "frustrated "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*disgusted\S*" , "disgusted "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*disgrace\S*" , "disgrace "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*happy\S*" , "happy "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*great\S*" , "great "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*thank you very much\S*" , "thank you very much "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*thank you customer service\S*" , "thank you customer service "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*awesome\S*" , "awesome "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*fantastic\S*" , "fantastic "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*well done\S*" , "well done"*3, regex=True, inplace = True)
df.tweet.replace(r"\S*time to change\S*" , "time to change "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*leaving\S*" , "leaving "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*bye\S*" , "bye "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*switch\S*" , "switch "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*covid\S*" , "covid "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*environment\S*" , "environment "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*sustainability\S*" , "sustainability "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*fossil\S*" , "fossil "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*coal\S*" , "coal "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*fuel\S*" , "fuel "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*climate\S*" , "climate "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*carbon\S*" , "carbon "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*best\S*" , "best "*3, regex=True, inplace = True)
df.tweet.replace(r"\S*wonderfull\S*" , "wonderfull "*3, regex=True, inplace = True)

# %%
import re

def remove_unicode(text):

    try:
        text = text.encode("latin_1").decode("raw_unicode_escape").encode('utf-16', 'surrogatepass').decode('utf-16')
    except:
        text = text
        
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
        "]+", re.UNICODE)
    
    text = re.sub(emoji_pattern, '', text)
    text = ''.join(text.split('\\n')) # to remove uncompiled \n
    text = re.sub('\n', '', text)     # to remove compiled \n

    return text

# %%
# get and adjust the stop words

import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = stopwords.words('english')
# tokens_without_sw=[t for t in list_data2 if t not in stop_words]
include = ["until","against","most","before","after","more","over","under","no","same","when","why","how","any"]
[stop_words.remove(i) for i in include]
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'between', 'into', 'through', 'during', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'again', 'further', 'then', 'once', 'here', 'there', 'where', 'all', 'both', 'each', 'few', 'other', 'some', 'such', 'nor', 'not', 'only', 'own', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o',
# ...

# %%
def clean_data(text, small_word_lmt=0,stop_words = stop_words,
               extra_words=["bank","zar","us","jp","ive","got","get","amp","citi","ubs","im","zs","rit","uk","ing"]):
    
    text = remove_unicode(text)
    list_data2=[]
    sentence=text.lower().split(' ')
    for word in sentence:
        if not (word.startswith('@') | word.startswith('#') | word.startswith('http')) \
           and len(word) > small_word_lmt \
           and word not in extra_words \
           and word not in stop_words \
           and word.isalpha():
            list_data2.append(word)

    return " ".join(list_data2)

# %%
df.tweet = df.tweet.apply(clean_data)

# %%
#adjustment for non-english words

nltk.download('words')
eng_words = set(nltk.corpus.words.words())
df.tweet = df.tweet.apply(lambda x: " ".join([i for i in nltk.wordpunct_tokenize(x) if i in eng_words]))
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
#Aryamaan preprocessing
data = df.tweet.tolist()

import math
from tabulate import tabulate
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
def reduce_func(x):
    return x**0.5
data_map = {}
all_words = set()
for i, sen in enumerate(data):
    for word in sen.split(" "):
        if word in stopwords.words('english'): continue
        low_word = word.lower()
        data_map[low_word] = data_map.get(low_word, set())
        data_map[low_word].add(i)
        all_words.add(low_word)
deg = {}
deg_list = []
for wrd1 in all_words:
    tmp_deg = 0
    for wrd2 in all_words:
        common = data_map[wrd1] & data_map[wrd2]
        if len(common) == 0: continue
        tmp_deg += reduce_func(len(common))
    deg[wrd1] = tmp_deg
for wrd in deg:
    deg_list.append((wrd, deg[wrd]))
deg_list = sorted(deg_list, key=lambda x : x[1], reverse=True)
print(tabulate(deg_list, headers=['word', 'deg of importance']))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# word                deg of importance
# ----------------  -------------------
# thank                      2235.69
# account                    1716.59
# hello                      1705.84
# back                       1701.5
# wait                       1403.1
# please                     1386.58
# still                      1287.72
# applied                    1183
# business                   1123.23
# call                       1101.51
# help                       1086.49
# would                      1047.75
# loan                        942.208
# like                        942.086
# banking                     935.027
# need                        931.802
# time                        921.312
# one                         918.732
# may                         913.3
# customer                    895.408
# ...

# %%
df_clean = df.tweet
df_clean.shape
# Out:
# (2967,)

# %%
df_clean = df_clean.dropna()
df_clean.shape
# Out:
# (2967,)

# %%
list_data = df_clean.to_list()
list_data = [str(sent) for sent in list_data]

# %%
from sentence_transformers import SentenceTransformer

# %%
# distilbert-base-nli-mean-tokens
# paraphrase-distilroberta-base-v1

# %%
model=SentenceTransformer('distilbert-base-nli-mean-tokens')
embeddings1 = model.encode(list_data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/93 [00:00<?, ?it/s]

# %%
model=SentenceTransformer('paraphrase-distilroberta-base-v1')
embeddings2 = model.encode(list_data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/93 [00:00<?, ?it/s]

# %%
embeddings1_norm = embeddings1 /  np.linalg.norm(embeddings1, axis=1, keepdims=True)
embeddings2_norm = embeddings2 /  np.linalg.norm(embeddings2, axis=1, keepdims=True)

# %%
import umap

# %%
from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE

# %%
UMAP_bert1 = umap.UMAP(n_components=2).fit_transform(embeddings1)
UMAP_bert1_norm = umap.UMAP(n_components=2).fit_transform(embeddings1_norm)

UMAP_bert2 = umap.UMAP(n_components=2).fit_transform(embeddings2)
UMAP_bert2_norm = umap.UMAP(n_components=2).fit_transform(embeddings2_norm)

#n_neighbors=10, min_dist=0.0,

# %%
PCA_bert1 = PCA(n_components=2).fit_transform(embeddings1)
PCA_bert1_norm = PCA(n_components=2).fit_transform(embeddings1_norm)

PCA_bert2 = PCA(n_components=2).fit_transform(embeddings2)
PCA_bert2_norm = PCA(n_components=2).fit_transform(embeddings2_norm)

# %%
tSNE_bert1 = TSNE(n_components=2).fit_transform(embeddings1)
tSNE_bert1_norm = TSNE(n_components=2).fit_transform(embeddings1_norm)

tSNE_bert2 = TSNE(n_components=2).fit_transform(embeddings2)
tSNE_bert2_norm = TSNE(n_components=2).fit_transform(embeddings2_norm)

# %%
#inertia

kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(UMAP_bert2)
                for k in range(1, 10)]
inertias = [model.inertia_ for model in kmeans_per_k]

plt.plot(range(1, 10), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
def cluster_results(Kmeans_clusters=5):
    
    ClusterDict = {}
    global dim_embeddings
    dim_embeddings = {"UMAP_bert1" : UMAP_bert1, "UMAP_bert1_norm" : UMAP_bert1_norm, 
                                      "UMAP_bert2" : UMAP_bert2, "UMAP_bert2_norm" : UMAP_bert2_norm,
                                      "PCA_bert1" : PCA_bert1, "PCA_bert1_norm" : PCA_bert1_norm, 
                                      "PCA_bert2" : PCA_bert2, "PCA_bert2_norm" : PCA_bert2_norm,
                                      "tSNE_bert1" : tSNE_bert1, "tSNE_bert1_norm" :  tSNE_bert1_norm, 
                                      "tSNE_bert2" : tSNE_bert2, "tSNE_bert2_norm" : tSNE_bert2_norm}
    
    for key, val in dim_embeddings.items():
        ClusterDict[key] = KMeans(n_clusters=Kmeans_clusters).fit_predict(val)

    return ClusterDict

# %%
clustering_result = cluster_results()

# %%
import matplotlib.pyplot as plt
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')
import seaborn as sns
sns.set(style='white', rc={'figure.figsize':(10,8)})


def plot(cluster = clustering_result):    
    
    for clustee_name, clustee in cluster.items():
        clustered = (clustee >= 0)
        reduced_dim = dim_embeddings[clustee_name]
            
        print(f"----------{clustee_name}--------------------")

        unique, counts = np.unique(clustee, return_counts=True)
        print(dict(zip(unique, counts)))

        plt.scatter(reduced_dim[~clustered, 0],
                    reduced_dim[~clustered, 1],
                    c=(0.5,0.5,0.5),
                    # s=1,
                    alpha=0.5
                    )
        plt.scatter(reduced_dim[clustered, 0],
                    reduced_dim[clustered, 1],
                    c=clustee[clustered],
                    # s=1,
                    cmap='Spectral')
        plt.show()

# %%
plot()
# Out:
# ----------UMAP_bert1--------------------
# {0: 1033, 1: 897, 2: 42, 3: 503, 4: 492}
# ----------UMAP_bert1_norm--------------------
# {0: 942, 1: 1040, 2: 548, 3: 44, 4: 393}
# ----------UMAP_bert2--------------------
# {0: 917, 1: 957, 2: 39, 3: 30, 4: 1024}
# ----------UMAP_bert2_norm--------------------
# {0: 613, 1: 600, 2: 41, 3: 696, 4: 1017}
# ----------PCA_bert1--------------------
# {0: 756, 1: 901, 2: 385, 3: 585, 4: 340}
# ----------PCA_bert1_norm--------------------
# {0: 590, 1: 441, 2: 755, 3: 350, 4: 831}
# ----------PCA_bert2--------------------
# {0: 735, 1: 235, 2: 683, 3: 503, 4: 811}
# ----------PCA_bert2_norm--------------------
# {0: 483, 1: 750, 2: 825, 3: 273, 4: 636}
# ----------tSNE_bert1--------------------
# {0: 560, 1: 569, 2: 615, 3: 583, 4: 640}
# ----------tSNE_bert1_norm--------------------
# {0: 569, 1: 642, 2: 654, 3: 624, 4: 478}
# ----------tSNE_bert2--------------------
# {0: 623, 1: 599, 2: 518, 3: 509, 4: 718}
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def tfidfmatrix(data, vectorizer):
    terms = vectorizer.fit_transform(data)
    return pd.DataFrame(terms.toarray(), columns = vectorizer.get_feature_names())

# %%
def cluster_words(clustering_result=clustering_result, top_n = 15, show_cross = False):
    for name, value in clustering_result.items():
        print(f"===================================={name}=============================================")
    
        #creatin new df in order to groupby same clusters
        cluster = value
        docs = pd.DataFrame(df_clean)
        docs["cluster"] = cluster

        labeled_docs = docs.groupby(["cluster"], as_index=False).agg({"tweet": " ".join})

        try : 
            del labeled_docs_try
        except :
            pass
        labeled_docs_try =pd.DataFrame(df_clean)
        labeled_docs_try["labels"] = df.labels
        labeled_docs_try["cluster"] = docs.cluster
        labeled_docs_try.head(50)
        cross = pd.crosstab(labeled_docs_try.labels, labeled_docs_try.cluster)
        if show_cross:
            display(cross)
        else: pass
                
        tfidf_vec = TfidfVectorizer()
        tfidf_mat = tfidfmatrix(labeled_docs.tweet, tfidf_vec)
        
        global most_common
        most_common = pd.DataFrame({n: tfidf_mat.T[col].nlargest(top_n).index.tolist() 
                                for n, col in enumerate(tfidf_mat.T)}).T
        most_common.index = np.unique(cluster)
        display(most_common)

# %%
cluster_words()
# Out:
# ====================================UMAP_bert1=============================================
#         0      1       2        3        4            5        6         7   \
# 0     wait     no   still  account     back      applied     days      loan
# 1    thank  happy   hello    covid  account       please     back   banking
# 2  contest   join    mate  lottery   answer  corporation     honk  shanghai
# 3    thank  hello  please    great      any         back     help     sorry
# 4    worst  worse   awful  account    thank        hello  banking      wait
#
#      8           9         10     11        12          13           14
# 0  cant       thank    feeder  after  business         any  application
# 1  best       great      wait   team      call        send         help
# 2   ask  experience       put  thats     would   abandoned      abigail
# 3   how        much      team    may      know  appreciate         more
# ...
