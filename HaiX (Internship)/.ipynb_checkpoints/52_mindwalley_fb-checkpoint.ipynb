# %%
import time
start = time.time()

# %%
import re
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import umap
import nltk
import spacy
import string
import hdbscan

import preprocessor as p

import matplotlib.pyplot as plt
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')
import seaborn as sns
sns.set(style='white', rc={'figure.figsize':(10,8)})

np.random.seed(42)
# %config Completer.use_jedi = False
pd.set_option('display.max_columns', 30)
# pd.set_option('display.max_rows', 100)

nlp = spacy.load("en_core_web_sm")

# %%
df = pd.read_csv('octopus_energy_fb_comments.csv')
df.rename(columns={"fb_comment":"comments"},inplace=True)
df.head()
# Out:
#    Unnamed: 0                                           comments
# 0           0                              Congratulations Laura
# 1           1  Rang u as my smart meter ain't working on scre...
# 2           2  I just applied switched to Octopus , but can I...
# 3           3        What do I need to do to get smart metres...
# 4           4                                Could of phoned me

# %%
df.comments.replace("\n" , " ", regex=True, inplace = True)
df.comments=df.comments.apply(lambda x:p.clean(str(x)))

# %%
df.replace('nan', np.nan, inplace = True)
df.replace('', np.nan, inplace = True)
df.replace('do', np.nan, inplace = True)
df = df.dropna()

# %%
list_data = df.comments.unique().tolist()

# %%
from sentence_transformers import SentenceTransformer

# %%
# distilbert-base-nli-mean-tokens
# paraphrase-distilroberta-base-v1
# roberta-large-nli-stsb-mean-tokens
#allenai-specter

# %%
# %%time
model=SentenceTransformer('xlm-r-distilroberta-base-paraphrase-v1')
embeddings = model.encode(list_data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/23 [00:00<?, ?it/s]
# Wall time: 1min 5s

# %%
# %%time
best_model = umap.UMAP(n_components=5,min_dist=0.0).fit_transform(embeddings)

#n_neighbors=10, min_dist=0.0,

# %%
#inertia

kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(best_model)
                for k in range(1, 10)]
inertias = [model.inertia_ for model in kmeans_per_k]

plt.plot(range(1, 10), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.show()

# %%
# from nltk.cluster import KMeansClusterer,euclidean_distance
# clusterer =KMeansClusterer(6,euclidean_distance)
# cluster=np.array(clusterer.cluster(best_model,True))

# %%
# cluster = KMeans(n_clusters=1, init="k-means++").fit_predict(best_model)

# %%
cluster = hdbscan.HDBSCAN().fit_predict(best_model)

# %%
def plot(cluster = cluster):    

    clustered = (cluster >= 0)
    reduced_dim = umap.UMAP(n_components=2).fit_transform(embeddings)



    unique, counts = np.unique(cluster, return_counts=True)
    print(dict(zip(unique, counts)))

    plt.scatter(reduced_dim[~clustered, 0],
                reduced_dim[~clustered, 1],
                c=(0.5,0.5,0.5),
                # s=1,
                alpha=0.5
                )
    plt.scatter(reduced_dim[clustered, 0],
                reduced_dim[clustered, 1],
                c=cluster[clustered],
                # s=1,
                cmap='hsv')
    plt.show()

# %%
plot()
# Out:
# {-1: 192, 0: 25, 1: 35, 2: 49, 3: 6, 4: 90, 5: 22, 6: 11, 7: 9, 8: 6, 9: 66, 10: 24, 11: 7, 12: 7, 13: 10, 14: 12, 15: 7, 16: 14, 17: 6, 18: 26, 19: 8, 20: 65, 21: 17, 22: 13, 23: 9}

# %%
len(cluster)
# Out:
# 736

# %%
def word_root(text):
    list_data3=[]
    doc = nlp(text)
    for token in doc:
        if token.text.isalpha() and len(token.text)>2:
            lemma = token.lemma_
            list_data3.append(lemma)
        else:pass
    return " ".join(list_data3)

# %%
docs = pd.DataFrame(list_data,columns=["comments"])
docs["cluster"] = cluster
labeled_docs = docs.groupby(["cluster"], as_index=False).agg({"comments": " ".join})
labeled_docs.comments = labeled_docs.comments.apply(lambda x: word_root(str(x).lower()))  
labeled_docs
# Out:
#     cluster                                           comments
# 0        -1  congratulation laura there any news come north...
# 1         0  your wheel fortune scam you need publish who w...
# 2         1  talk about eagle eye your consumption enter ap...
# 3         2  fantastic news well do xxx amazing next one br...
# 4         3  jame warwick snow wanna this windsleydale farm...
# 5         4  lisa maureen jenkin see the tonight programme ...
# 6         5  well do awesome company good energy company st...
# 7         6  clever stuff just need electric car for lol th...
# 8         7  why let submit gas reading online say not inst...
# 9         8  what about loyal customer all get increase bil...
# 10        9  ring smart meter work screen for dual fuel sti...
# 11       10  about change energy supplier and interested gr...
# 12       11  still wait for response be over month now for ...
# 13       12  remind jasper carrotts insurance claim lol can...
# 14       13  can not wait switch octopus be with scottish p...
# 15       14  also quite like get response email question wh...
# 16       15  get the code easy that clever one fab offer be...
# 17       16  octopus energy be you check email send the hel...
# 18       17  octopus send few email last week but not hear ...
# 19       18  good decision join these can wait for the fina...
# 20       19  can you make the youtube link clickable any go...
# 21       20  could phone sure be the millionth customer but...
# 22       21  well do octopus another happy customer with oc...
# 23       22  nice one octopus energy lucky laura nice hear ...
# 24       23  octopus tastic company wind ston churchill oct...

# %%
# %%time
array_text = labeled_docs.comments.tolist()
from sentence_transformers import SentenceTransformer, util

sentences = array_text[1:]

#Encode all sentences
embeddings = model.encode(sentences)

#Compute cosine similarity between all pairs
cos_sim = util.pytorch_cos_sim(embeddings, embeddings)

#Add all pairs to a list with their cosine similarity score
all_sentence_combinations = []
for i in range(len(cos_sim)-1):
    for j in range(i+1, len(cos_sim)):
        all_sentence_combinations.append([cos_sim[i][j], i, j])

#Sort list by the highest cosine similarity score
all_sentence_combinations = sorted(all_sentence_combinations, key=lambda x: x[0], reverse=True)
similar = []
print("Top similar pairs:")
for score, i, j in all_sentence_combinations:
    print("cluster {} \t cluster {} \t similarity: {:.4f}".format(i+1, j+1, cos_sim[i][j]))
    similar.append((score,i+1,j+1))
# Out:
# Top similar pairs:
# cluster 17 	 cluster 18 	 similarity: 0.7272
# cluster 18 	 cluster 19 	 similarity: 0.7237
# cluster 19 	 cluster 23 	 similarity: 0.7231
# cluster 22 	 cluster 23 	 similarity: 0.7135
# cluster 19 	 cluster 22 	 similarity: 0.7054
# cluster 14 	 cluster 22 	 similarity: 0.6831
# cluster 23 	 cluster 24 	 similarity: 0.6793
# cluster 10 	 cluster 17 	 similarity: 0.6775
# cluster 14 	 cluster 17 	 similarity: 0.6763
# cluster 14 	 cluster 19 	 similarity: 0.6740
# cluster 11 	 cluster 23 	 similarity: 0.6656
# cluster 14 	 cluster 18 	 similarity: 0.6637
# cluster 18 	 cluster 22 	 similarity: 0.6621
# cluster 10 	 cluster 11 	 similarity: 0.6573
# cluster 5 	 cluster 13 	 similarity: 0.1399
# cluster 5 	 cluster 9 	 similarity: 0.1392
# cluster 5 	 cluster 22 	 similarity: 0.1392
# cluster 7 	 cluster 24 	 similarity: 0.1383
# cluster 21 	 cluster 24 	 similarity: 0.1377
# cluster 5 	 cluster 21 	 similarity: 0.1308
# cluster 13 	 cluster 22 	 similarity: 0.1259
# cluster 5 	 cluster 15 	 similarity: 0.1231
# cluster 4 	 cluster 11 	 similarity: 0.1192
# cluster 4 	 cluster 20 	 similarity: 0.1125
# cluster 5 	 cluster 7 	 similarity: 0.1068
# cluster 7 	 cluster 18 	 similarity: 0.1064
# cluster 7 	 cluster 20 	 similarity: 0.1045
# cluster 5 	 cluster 14 	 similarity: 0.1033
# cluster 5 	 cluster 18 	 similarity: 0.0898
# cluster 1 	 cluster 24 	 similarity: 0.0865
# cluster 4 	 cluster 16 	 similarity: 0.0845
# cluster 13 	 cluster 24 	 similarity: 0.0754
# cluster 16 	 cluster 24 	 similarity: 0.0751
# cluster 4 	 cluster 15 	 similarity: 0.0750
# cluster 15 	 cluster 24 	 similarity: 0.0560
# cluster 7 	 cluster 13 	 similarity: 0.0557
# cluster 4 	 cluster 10 	 similarity: 0.0550
# cluster 4 	 cluster 21 	 similarity: 0.0536
# cluster 9 	 cluster 24 	 similarity: 0.0527
# cluster 4 	 cluster 9 	 similarity: 0.0448
# cluster 4 	 cluster 19 	 similarity: 0.0362
# cluster 1 	 cluster 4 	 similarity: 0.0346
# cluster 4 	 cluster 18 	 similarity: 0.0264
# cluster 12 	 cluster 24 	 similarity: 0.0251
# cluster 4 	 cluster 17 	 similarity: 0.0131
# cluster 4 	 cluster 12 	 similarity: 0.0093
# cluster 4 	 cluster 14 	 similarity: -0.0074
# cluster 4 	 cluster 22 	 similarity: -0.0144

# %%
# %%time
i=0
while similar[i][0]>0.40:
    one, two = sorted([similar[i][1],similar[i][2]])
    if labeled_docs.comments[one] == "" and labeled_docs.comments[two] == "":
        pass
    elif labeled_docs.comments[one] == "" and labeled_docs.comments[two] != "":
        labeled_docs.comments[one] = labeled_docs.comments[two]
    else:
        labeled_docs.comments[one] = labeled_docs.comments[one] +" "+labeled_docs.comments[two]
    labeled_docs.comments[two]=""
    i+=1
# Out:
# <ipython-input-21-ecf0ff23749c>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled_docs.comments[one] = labeled_docs.comments[one] +" "+labeled_docs.comments[two]
# <ipython-input-21-ecf0ff23749c>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled_docs.comments[two]=""
# <ipython-input-21-ecf0ff23749c>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled_docs.comments[one] = labeled_docs.comments[two]

# %%
labeled_docs.replace('', np.nan, inplace = True)
labeled_docs=labeled_docs.dropna()
labeled_docs
# Out:
#     cluster                                           comments
# 0        -1  congratulation laura there any news come north...
# 1         0  your wheel fortune scam you need publish who w...
# 2         1  talk about eagle eye your consumption enter ap...
# 4         3  jame warwick snow wanna this windsleydale farm...
# 5         4  lisa maureen jenkin see the tonight programme ...
# 6         5  what about loyal customer all get increase bil...
# 8         7  why let submit gas reading online say not inst...
# 10        9  ring smart meter work screen for dual fuel sti...
# 12       11  still wait for response be over month now for ...
# 16       15  get the code easy that clever one fab offer be...
# 20       19  can you make the youtube link clickable any go...

# %%
# %%time
array_text = labeled_docs.comments.tolist()
from sentence_transformers import SentenceTransformer, util

sentences = array_text[1:]

#Encode all sentences
embeddings = model.encode(sentences)

#Compute cosine similarity between all pairs
cos_sim = util.pytorch_cos_sim(embeddings, embeddings)

#Add all pairs to a list with their cosine similarity score
all_sentence_combinations = []
for i in range(len(cos_sim)-1):
    for j in range(i+1, len(cos_sim)):
        all_sentence_combinations.append([cos_sim[i][j], i, j])

#Sort list by the highest cosine similarity score
all_sentence_combinations = sorted(all_sentence_combinations, key=lambda x: x[0], reverse=True)
similar = []
print("Top similar pairs:")
for score, i, j in all_sentence_combinations:
    print("cluster {} \t cluster {} \t similarity: {:.4f}".format(i+1, j+1, cos_sim[i][j]))
    similar.append((score,i+1,j+1))
# Out:
# Top similar pairs:
# cluster 5 	 cluster 8 	 similarity: 0.4397
# cluster 5 	 cluster 6 	 similarity: 0.4163
# cluster 6 	 cluster 7 	 similarity: 0.3997
# cluster 1 	 cluster 4 	 similarity: 0.3771
# cluster 1 	 cluster 9 	 similarity: 0.3688
# cluster 5 	 cluster 7 	 similarity: 0.3641
# cluster 2 	 cluster 8 	 similarity: 0.3398
# cluster 1 	 cluster 8 	 similarity: 0.3368
# cluster 6 	 cluster 10 	 similarity: 0.3316
# cluster 1 	 cluster 7 	 similarity: 0.3271
# cluster 1 	 cluster 2 	 similarity: 0.3269
# cluster 2 	 cluster 7 	 similarity: 0.3213
# cluster 6 	 cluster 9 	 similarity: 0.3208
# cluster 9 	 cluster 10 	 similarity: 0.3203
# cluster 2 	 cluster 9 	 similarity: 0.3136
# cluster 5 	 cluster 9 	 similarity: 0.2965
# cluster 7 	 cluster 8 	 similarity: 0.2897
# cluster 1 	 cluster 6 	 similarity: 0.2883
# cluster 8 	 cluster 9 	 similarity: 0.2803
# cluster 2 	 cluster 4 	 similarity: 0.2793
# cluster 6 	 cluster 8 	 similarity: 0.2752
# cluster 2 	 cluster 5 	 similarity: 0.2734
# cluster 5 	 cluster 10 	 similarity: 0.2666
# cluster 7 	 cluster 9 	 similarity: 0.2594
# cluster 1 	 cluster 5 	 similarity: 0.2557
# cluster 8 	 cluster 10 	 similarity: 0.2501
# cluster 1 	 cluster 10 	 similarity: 0.2458
# cluster 4 	 cluster 9 	 similarity: 0.2435
# cluster 4 	 cluster 7 	 similarity: 0.2393
# cluster 2 	 cluster 6 	 similarity: 0.2263
# cluster 7 	 cluster 10 	 similarity: 0.2262
# cluster 2 	 cluster 10 	 similarity: 0.2249
# cluster 4 	 cluster 8 	 similarity: 0.1739
# cluster 2 	 cluster 3 	 similarity: 0.1737
# cluster 3 	 cluster 4 	 similarity: 0.1723
# cluster 4 	 cluster 10 	 similarity: 0.1628
# cluster 3 	 cluster 6 	 similarity: 0.1610
# cluster 4 	 cluster 6 	 similarity: 0.1476
# cluster 4 	 cluster 5 	 similarity: 0.1452
# cluster 3 	 cluster 10 	 similarity: 0.1125
# cluster 3 	 cluster 9 	 similarity: 0.0845
# cluster 3 	 cluster 7 	 similarity: 0.0550
# cluster 3 	 cluster 5 	 similarity: 0.0531
# cluster 1 	 cluster 3 	 similarity: 0.0346
# cluster 3 	 cluster 8 	 similarity: 0.0093

# %%
# %%time
i=0
while similar[i][0]>0.40:
    one, two = sorted([similar[i][1],similar[i][2]])
    if labeled_docs.comments[one] == "" and labeled_docs.comments[two] == "":
        pass
    elif labeled_docs.comments[one] == "" and labeled_docs.comments[two] != "":
        labeled_docs.comments[one] = labeled_docs.comments[two]
    else:
        labeled_docs.comments[one] = labeled_docs.comments[one] +" "+labeled_docs.comments[two]
    labeled_docs.comments[two]=""
    i+=1
# Out:
# <ipython-input-24-b03d7faa43c8>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled_docs.comments[one] = labeled_docs.comments[one] +" "+labeled_docs.comments[two]
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\IPython\core\interactiveshell.py:3418: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)
# <ipython-input-24-b03d7faa43c8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   labeled_docs.comments[two]=""

# %%
labeled_docs.replace('', np.nan, inplace = True)
labeled_docs=labeled_docs.dropna()
# Out:
# c:\users\user\appdata\local\programs\python\python38\lib\site-packages\pandas\core\frame.py:4521: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
labeled_docs
# Out:
#     cluster                                           comments
# 0        -1  congratulation laura there any news come north...
# 1         0  your wheel fortune scam you need publish who w...
# 2         1  talk about eagle eye your consumption enter ap...
# 4         3  jame warwick snow wanna this windsleydale farm...
# 5         4  lisa maureen jenkin see the tonight programme ...
# 10        9  ring smart meter work screen for dual fuel sti...
# 12       11  still wait for response be over month now for ...
# 16       15  get the code easy that clever one fab offer be...
# 20       19  can you make the youtube link clickable any go...

# %%
# %%time
from keybert import KeyBERT
array_text = labeled_docs.comments.tolist()
kw_extractor = KeyBERT(model=model)
bigram=[]
for j in range(len(array_text)-1):
    keywords = kw_extractor.extract_keywords(array_text[j+1],top_n=10,keyphrase_ngram_range=(2, 2))
    print(f'\033[1m   Bigram Cluster {j+1}: \033[0m' )
    print([word for word in keywords])
    bigram.append([word[0] for word in keywords])
# Out:
#    Bigram Cluster 1:
# [('scramble quiz', 0.5294), ('enter quiz', 0.5286), ('thankyou quiz', 0.5252), ('awesome quiz', 0.5225), ('great quiz', 0.5132), ('good quiz', 0.5036), ('nice quiz', 0.4673), ('answer prize', 0.4503), ('catch quiz', 0.4384), ('quiz great', 0.4368)]
#    Bigram Cluster 2:
# [('apple cake', 0.6154), ('cake apple', 0.5881), ('apple cookie', 0.5794), ('chocolate cake', 0.5615), ('apple chocolate', 0.5501), ('use cake', 0.5272), ('pie cupcake', 0.5175), ('apple pie', 0.5155), ('pie apple', 0.4971), ('cake make', 0.4958)]
#    Bigram Cluster 3:
# [('windirection windy', 0.7512), ('spinner windy', 0.7078), ('windy wind', 0.7075), ('farm windy', 0.6998), ('wing windiesel', 0.6916), ('wind face', 0.6808), ('lauper wind', 0.6691), ('windiesel vin', 0.6662), ('windy lauper', 0.665), ('diesel windirection', 0.6497)]
#    Bigram Cluster 4:
# [('tonight programme', 0.5345), ('programme night', 0.497), ('jenkin tonight', 0.4522), ('lisa maureen', 0.4019), ('lee quiz', 0.3767), ('clinton jamie', 0.3663), ('dale quiz', 0.3601), ('prentice william', 0.3593), ('quiz night', 0.3567), ('night andrew', 0.3515)]
#    Bigram Cluster 5:
# [('read meter', 0.5258), ('install meter', 0.5225), ('smart meter', 0.517), ('reading meter', 0.5109), ('meter octopus', 0.5075), ('ask meter', 0.4988), ('fitting meter', 0.4979), ('say meter', 0.4954), ('regard meter', 0.4903), ('submit meter', 0.4821)]
#    Bigram Cluster 6:
# [('look wait', 0.4266), ('click month', 0.4121), ('scroll month', 0.4093), ('response month', 0.3987), ('wait communication', 0.3967), ('time date', 0.3943), ('month time', 0.3899), ('calendar click', 0.3841), ('wait response', 0.3707), ('age try', 0.3701)]
#    Bigram Cluster 7:
# [('want code', 0.5762), ('code want', 0.5675), ('code care', 0.5221), ('fancy code', 0.5176), ('code easy', 0.5081), ('use code', 0.5063), ('code tempt', 0.4973), ('code darren', 0.4368), ('electic car', 0.3573), ('car ask', 0.3521)]
#    Bigram Cluster 8:
# [('link clickable', 0.5039), ('click referral', 0.5003), ('link friend', 0.4446), ('youtube link', 0.4442), ('god link', 0.4439), ('referal link', 0.4274), ('referral link', 0.4261), ('share referral', 0.4104), ('link referal', 0.4063), ('link say', 0.3978)]

# %%
# %%time
unigram=[]
for j in range(len(array_text)-1):
    keywords = kw_extractor.extract_keywords(array_text[j+1],top_n=10,keyphrase_ngram_range=(1, 1))
    print(f'\033[1m   Unigram Cluster {j+1}: \033[0m' )
    print([word for word in keywords])
    unigram.append([word[0] for word in keywords])
# Out:
#    Unigram Cluster 1:
# [('prize', 0.3744), ('quiz', 0.352), ('winner', 0.3383), ('award', 0.3162), ('congratulation', 0.3075), ('luck', 0.295), ('thankyou', 0.2885), ('lucky', 0.2815), ('deserve', 0.2668), ('excellent', 0.2631)]
#    Unigram Cluster 2:
# [('cake', 0.455), ('cupcake', 0.4068), ('apple', 0.4007), ('chocolate', 0.3787), ('cookie', 0.3695), ('octocake', 0.3692), ('cranberry', 0.33), ('pastry', 0.3074), ('enjoy', 0.2814), ('entice', 0.2667)]
#    Unigram Cluster 3:
# [('windiesel', 0.6791), ('windy', 0.6717), ('wind', 0.6301), ('windirection', 0.6193), ('windsleydale', 0.5278), ('snow', 0.372), ('diesel', 0.3478), ('farm', 0.3439), ('vin', 0.3381), ('face', 0.3377)]
#    Unigram Cluster 4:
# [('programme', 0.3511), ('tonight', 0.3463), ('evening', 0.3296), ('liz', 0.3128), ('lisa', 0.3056), ('garnett', 0.3031), ('quizs', 0.2974), ('lorna', 0.2908), ('jess', 0.2776), ('alex', 0.2753)]
#    Unigram Cluster 5:
# [('octopusenergy', 0.3916), ('meter', 0.3903), ('octopus', 0.3793), ('metre', 0.3422), ('octopuse', 0.3336), ('octoturny', 0.3293), ('electricity', 0.3223), ('utilitia', 0.302), ('electric', 0.2939), ('october', 0.289)]
#    Unigram Cluster 6:
# [('wait', 0.3399), ('try', 0.3125), ('calendar', 0.294), ('date', 0.2923), ('month', 0.2699), ('check', 0.2691), ('time', 0.2519), ('issue', 0.2386), ('await', 0.2383), ('year', 0.2377)]
#    Unigram Cluster 7:
# [('code', 0.4658), ('car', 0.3063), ('driver', 0.2349), ('say', 0.2331), ('clever', 0.2307), ('freya', 0.226), ('care', 0.2166), ('jamie', 0.2164), ('offer', 0.2113), ('katy', 0.2081)]
#    Unigram Cluster 8:
# [('link', 0.3436), ('clickable', 0.2987), ('click', 0.2661), ('shetterley', 0.1862), ('youtube', 0.1714), ('code', 0.1588), ('friend', 0.1583), ('hit', 0.1571), ('share', 0.1531), ('compare', 0.1495)]

# %%
for i in range(len(array_text)-1):
    clusterer=[]
    bigramer=[]
    print(f'\033[1m   Cluster {i+1}: \033[0m')
    [clusterer.append(j) for j in unigram[i]]
    clusterer.append(bigram[i][0])
    
    for word in bigram[i][0].split(" "):
        if word not in bigramer:
            bigramer.append(word)
    
    for each in bigram[i]:
        first,second=each.split(" ")
        if first != second and not(first in bigramer and second in bigramer):
            clusterer.append(each)
            if bigramer.append(first): first not in bigramer
            if bigramer.append(second): second not in bigramer
    print(clusterer)
# Out:
#    Cluster 1:
# ['prize', 'quiz', 'winner', 'award', 'congratulation', 'luck', 'thankyou', 'lucky', 'deserve', 'excellent', 'scramble quiz', 'enter quiz', 'thankyou quiz', 'awesome quiz', 'great quiz', 'good quiz', 'nice quiz', 'answer prize', 'catch quiz']
#    Cluster 2:
# ['cake', 'cupcake', 'apple', 'chocolate', 'cookie', 'octocake', 'cranberry', 'pastry', 'enjoy', 'entice', 'apple cake', 'apple cookie', 'chocolate cake', 'use cake', 'pie cupcake', 'cake make']
#    Cluster 3:
# ['windiesel', 'windy', 'wind', 'windirection', 'windsleydale', 'snow', 'diesel', 'farm', 'vin', 'face', 'windirection windy', 'spinner windy', 'windy wind', 'farm windy', 'wing windiesel', 'wind face', 'lauper wind', 'windiesel vin', 'diesel windirection']
#    Cluster 4:
# ['programme', 'tonight', 'evening', 'liz', 'lisa', 'garnett', 'quizs', 'lorna', 'jess', 'alex', 'tonight programme', 'programme night', 'jenkin tonight', 'lisa maureen', 'lee quiz', 'clinton jamie', 'dale quiz', 'prentice william', 'night andrew']
#    Cluster 5:
# ['octopusenergy', 'meter', 'octopus', 'metre', 'octopuse', 'octoturny', 'electricity', 'utilitia', 'electric', 'october', 'read meter', 'install meter', 'smart meter', 'reading meter', 'meter octopus', 'ask meter', 'fitting meter', 'say meter', 'regard meter', 'submit meter']
#    Cluster 6:
# ['wait', 'try', 'calendar', 'date', 'month', 'check', 'time', 'issue', 'await', 'year', 'look wait', 'click month', 'scroll month', 'response month', 'wait communication', 'time date', 'calendar click', 'age try']
#    Cluster 7:
# ['code', 'car', 'driver', 'say', 'clever', 'freya', 'care', 'jamie', 'offer', 'katy', 'want code', 'code care', 'fancy code', 'code easy', 'use code', 'code tempt', 'code darren', 'electic car', 'car ask']
#    Cluster 8:
# ['link', 'clickable', 'click', 'shetterley', 'youtube', 'code', 'friend', 'hit', 'share', 'compare', 'link clickable', 'click referral', 'link friend', 'youtube link', 'god link', 'referal link', 'share referral', 'link say']

# %%
end = time.time()
print(end - start)
# Out:
# 192.27775382995605

# %%
len(embeddings)
# Out:
# 10
