# %%
import re
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import nltk

import matplotlib.pyplot as plt
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')
import seaborn as sns
sns.set(style='white', rc={'figure.figsize':(10,8)})

np.random.seed(42)
# %config Completer.use_jedi = False
pd.set_option('display.max_columns', 30)
# pd.set_option('display.max_rows', 100)

lemmatizer = nltk.WordNetLemmatizer()
stemmizer = nltk.PorterStemmer()

# %%
df = pd.read_csv('hsbc_twitter_DATA_not GENERAL.csv')
df.rename(columns={"NEW HUMAN CATEGORY\n 0-1000 /4000-4468 Michael\n 1000-2500 Mehmet \n 2500-4000 Aryamaan":"labels"}, inplace = True)
df.head()
# Out:
#                                                    tweet  \
# 0   2  @LondOgrad Hello Eugene, we do apologise for t...
# 1   8  @ncohen4 @CooperativeBank @HSBC @HSBCUKBusines...
# 2   9  @sharaola Good morning, sorry for your experie...
# 3  11        @Bounce_BackLoan Still not a peep from HSBC
# 4  15  @djm2481 @mgcmitchell @HSBC_UK Thanks for the ...
#
#   HUMAN CATEGORY\n ARYAMAAN:1-1000,4000-4468\n Michael-Mehmet:1000-4000  \
# 0                            CUSTOMER_SERVICE_ISSUES
# 1                                     BAD REPUTATION
# 2                            CUSTOMER_SERVICE_ISSUES
# 3                                              DELAY
# 4                          Customer Service Response
#
#                 SUB CATEGORY                   COMMENTS  \
# 0                        NaN       bad customer service
# 1                        NaN                        NaN
# 2                        NaN       bad customer service
# 3  Delay_in_bounce_back_loan  delay in bounce back loan
# 4                        NaN     customer service reply
#
#                       labels             SUB CATEGORY.1  \
# 0  Customer Service Response                        NaN
# 1                    General                        NaN
# 2  Customer Service Response                        NaN
# 3                      DELAY  Delay_in_bounce_back_loan
# 4  Customer Service Response                        NaN
#
#                   COMMENTS.1 human category (Tarun)  SUB CATEGORY.2  \
# 0     customer service reply                    NaN             NaN
# 1                        NaN                    NaN             NaN
# 2     customer service reply                    NaN             NaN
# 3  delay in bounce back loan                    NaN             NaN
# 4     customer service reply                    NaN             NaN
#
#    COMMENTS.2             NEW CATEGORY              keyword  \
# 0         NaN  customer_service issues                delay
# 1         NaN           Bad_reputation              unhappy
# 2         NaN  customer_service issues      customerservice
# 3         NaN    Delay_Bounceback_Loan  delay , no response
# 4         NaN                  General          any queries
#
#                          human - category  \
# 0                                   Delay
# 1               {'category': 'Reputation'
# 2  {'category': 'customer_service issues'
# 3         {'category': 'Bounce back loan'
# 4               {'category': 'Reputation'
#
#                                 human - Sub category  \
# 0                                     delay in calls
# 1                     subcategory': 'Bad reputation'
# 2                    subcategory': 'customerservice'
# 3            subcategory': 'Bounce back loan delays'
# 4  subcategory': 'General Response from Bank (tha...
#
#                                  Comment HUMAN CATGEORY_NEW(ARYA)  \
# 0                            Huge Queues  customer_service_issues
# 1  worst experience from customer – mess           BAD_REPUTATION
# 2             General response from bank                  General
# 3                               No reply    DELAY_BOUNCEBACK_LOAN
# 4             General response from bank                      NaN
#
#               location   COMMENTS (FROM PARIJAAT)  \
# 0           London, UK                        NaN
# 1    Plymouth, England                        NaN
# 2         Cairo, Egypt  General message from hsbc
# 3  Enschede, Nederland                      DELAY
# 4       United Kingdom                        NaN
#
#                           Category                               Sub-category
# 0             {'category': 'Delay'  subcategory': 'Delay in bounce back loan'
# 1        {'category': 'Reputation'            subcategory': 'Good reputation'
# 2        {'category': 'Reputation'            subcategory': 'Good reputation'
# 3  {'category': 'Bounce back loan'    subcategory': 'Bounce back loan delays'
# 4        {'category': 'Reputation'            subcategory': 'Good reputation'

# %%
# reducing General Data 1500
drop_indices = np.random.choice(df.loc[df["labels"]=="General"].index, 1500, replace=False)
df = df.drop(drop_indices)

# %%
df.labels.value_counts()
# Out:
# General                      769
# DELAY                        716
# Customer Service Response    653
# BAD REPUTATION               229
# CUSTOMER_SERVICE_ISSUES      227
# Customer Query               168
# GOOD REPUTATION              101
# COVID19                       50
# CHURN                         37
# ESG                            6
# Junk                           4
# Language                       2
# Name: labels, dtype: int64

# %%
# label = pd.DataFrame(df.groupby("labels", as_index=False)["tweet"].apply(lambda x: " ".join(x)))
# bad_repu = label[label.labels == "BAD REPUTATION"]["reviewText"].tolist()

# %%
import string
def remove_punc(txt):
    txt = "".join([c for c in txt if c not in string.punctuation])
    txt = txt.replace("\n", " ")
    return txt.lower()
df.tweet = df.tweet.apply(lambda x: remove_punc(x))

# %%
#     text = remove_unicode(text)
#     not (word.startswith('@') | word.startswith('#') | word.startswith('http')) \
#     and len(word) > small_word_lmt \
#     and word not in stop_words \
#     and word.isalpha()
# word not in extra_words
# replace(r"\S*corona\S*" , "covid", regex=True, inplace = True)

# %%
replace_word = {"thanks":"thank","covid":"covid", "corona":"covid", "bouncebackloan":"bounce back loan",
                "noresponse":"no response","customers":"customer", "bounceback":"bounce back",
                "backloan":"backloan","on hold":"on_hold", "bbl":"bounce back loan"}
for key, value in replace_word.items():
    df.tweet.replace(f"\S*{key}\S*" , f"{value}", regex=True, inplace = True)

# %%
junk_words = "year barclays hsbcin amp like an no any since after banking im there out how starlingbank starling one only again over other then am may some do cant about banks would could its even their after has them get got within now all just if what or at had hsbcukbusiness up by into will an was our us so been hsbcuk co om ke ha gone your we can from as but to the hsbc and of you for are have they is my hsbc_uk with it in on this ðÿ be not bank me that"
junk_words_list = junk_words.split(" ")

# %%
def remove_unicode(text):

    try:
        text = text.encode("latin_1").decode("raw_unicode_escape").encode('utf-16', 'surrogatepass').decode('utf-16')
    except:
        text = text
        
    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
        "]+", re.UNICODE)
    
    text = re.sub(emoji_pattern, '', text)
    text = ''.join(text.split('\\n')) # to remove uncompiled \n
    text = re.sub('\n', '', text)     # to remove compiled \n

    return text

# %%
def clean_data(text, small_word_lmt=0, extra_words=junk_words_list,replace_word=replace_word):
    list_data2=[]
    text = remove_unicode(text)
    sentence=text.split(' ')
    for word in sentence:
        if word == "hi":
            word = word.replace("hi", "hello")
        if not word.startswith('http') \
           and word.isalpha() \
           and word not in extra_words:
            word = lemmatizer.lemmatize(word)
            list_data2.append(word)
    return " ".join(list_data2)
df.tweet = df.tweet.apply(lambda x: clean_data(x))

# %%
lemmatizer.lemmatize("apologise")
# Out:
# 'apologise'

# %%
stemmizer.stem('apologise')
# Out:
# 'apologis'

# %%
#adjustment for non-english words

# nltk.download('words')
# eng_words = set(nltk.corpus.words.words())
# df["eng"] = df.tweet.apply(lambda x: " ".join([i for i in nltk.wordpunct_tokenize(x) if i in eng_words]))
# df["noneng"] = df.tweet.apply(lambda x: " ".join([i for i in nltk.wordpunct_tokenize(x) if i not in eng_words]))
# df.noneng.tolist()

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = nltk.collocations.BigramCollocationFinder.from_documents([comment.split() for comment in df.tweet])
# Filter only those that occur at least 50 times
finder.apply_freq_filter(50)
bigram_scores = finder.score_ngrams(bigram_measures.pmi)

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = nltk.collocations.TrigramCollocationFinder.from_documents([comment.split() for comment in df.tweet])
# Filter only those that occur at least 50 times
finder.apply_freq_filter(50)
trigram_scores = finder.score_ngrams(trigram_measures.pmi)

# %%
bigram_pmi = pd.DataFrame(bigram_scores)
bigram_pmi.columns = ['bigram', 'pmi']
bigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)

# %%
trigram_pmi = pd.DataFrame(trigram_scores)
trigram_pmi.columns = ['trigram', 'pmi']
trigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)

# %%
bigrams
# Out:
# ['full name',
#  'credit card',
#  'thank writing',
#  'feeder account',
#  'still waiting',
#  'bounce back',
#  'back loan',
#  'business account',
#  'a feeder',
#  'i applied',
#  'hello thank',
#  'loan i',
#  'a bounce']

# %%
trigrams
# Out:
# ['bounce back loan', 'a feeder account', 'back loan i', 'a bounce back']

# %%
replace_word2 = {"bounce back loan":"bounce_back_loan", "full name":"full_name", "credit card":"credit_card",
                "thank writing":"thank_writing","feeder account":"feeder_account", "still waiting":"still_waiting",
                "business account":"business_account"}
for key, value in replace_word2.items():
    df.tweet.replace(f"\S*{key}\S*" , f"{value}", regex=True, inplace = True)

# %%
df[df.tweet.str.contains(r" an ")]["tweet"].tolist()
# df.tweet.str.contains(r" an ").sum()
# Out:
# ['tatacrucible an tatacrucible fromthequizmaster contest contestalert padmajaanu adeebashah',
#  'tatacrucible an tatacrucible fromthequizmaster contest contestalert',
#  'tatacrucible an tatacrucible fromthequizmaster contest contestalert pritinivoriya khemkanidhi emnishant nidhirn chilledsup',
#  'tatacrucible fromthequizmaster contest an tatacrucible']

# %%
df.drop(df[df.tweet.str.contains("tatacrucible")].index, axis=0,inplace=True)

# %%
df_clean = df.tweet
df_clean.shape
# Out:
# (2910,)

# %%
df_clean = df_clean.dropna()
df_clean.shape
# Out:
# (2910,)

# %%
list_data = df_clean.to_list()
list_data = [str(sent) for sent in list_data]

# %%
from sentence_transformers import SentenceTransformer

# %%
# distilbert-base-nli-mean-tokens
# paraphrase-distilroberta-base-v1

# %%
model=SentenceTransformer('distilbert-base-nli-mean-tokens')
embeddings1 = model.encode(list_data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/91 [00:00<?, ?it/s]

# %%
model=SentenceTransformer('paraphrase-distilroberta-base-v1')
embeddings2 = model.encode(list_data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/91 [00:00<?, ?it/s]

# %%
embeddings1_norm = embeddings1 /  np.linalg.norm(embeddings1, axis=1, keepdims=True)
embeddings2_norm = embeddings2 /  np.linalg.norm(embeddings2, axis=1, keepdims=True)

# %%
import umap

# %%
from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE

# %%
UMAP_bert1 = umap.UMAP(n_components=2).fit_transform(embeddings1)
UMAP_bert1_norm = umap.UMAP(n_components=2).fit_transform(embeddings1_norm)

UMAP_bert2 = umap.UMAP(n_components=2).fit_transform(embeddings2)
UMAP_bert2_norm = umap.UMAP(n_components=2).fit_transform(embeddings2_norm)

#n_neighbors=10, min_dist=0.0,

# %%
PCA_bert1 = PCA(n_components=2).fit_transform(embeddings1)
PCA_bert1_norm = PCA(n_components=2).fit_transform(embeddings1_norm)

PCA_bert2 = PCA(n_components=2).fit_transform(embeddings2)
PCA_bert2_norm = PCA(n_components=2).fit_transform(embeddings2_norm)

# %%
tSNE_bert1 = TSNE(n_components=2).fit_transform(embeddings1)
tSNE_bert1_norm = TSNE(n_components=2).fit_transform(embeddings1_norm)

tSNE_bert2 = TSNE(n_components=2).fit_transform(embeddings2)
tSNE_bert2_norm = TSNE(n_components=2).fit_transform(embeddings2_norm)

# %%
#inertia

kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(UMAP_bert2)
                for k in range(1, 10)]
inertias = [model.inertia_ for model in kmeans_per_k]

plt.plot(range(1, 10), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.show()

# %%
def cluster_results(Kmeans_clusters=4):
    
    ClusterDict = {}
    global dim_embeddings
    dim_embeddings = {"UMAP_bert1" : UMAP_bert1, "UMAP_bert1_norm" : UMAP_bert1_norm, 
                                      "UMAP_bert2" : UMAP_bert2, "UMAP_bert2_norm" : UMAP_bert2_norm,
                                      "PCA_bert1" : PCA_bert1, "PCA_bert1_norm" : PCA_bert1_norm, 
                                      "PCA_bert2" : PCA_bert2, "PCA_bert2_norm" : PCA_bert2_norm,
                                      "tSNE_bert1" : tSNE_bert1, "tSNE_bert1_norm" :  tSNE_bert1_norm, 
                                      "tSNE_bert2" : tSNE_bert2, "tSNE_bert2_norm" : tSNE_bert2_norm}
    
    for key, val in dim_embeddings.items():
        ClusterDict[key] = KMeans(n_clusters=Kmeans_clusters).fit_predict(val)

    return ClusterDict

# %%
clustering_result = cluster_results()

# %%
def plot(cluster = clustering_result):    
    
    for clustee_name, clustee in cluster.items():
        clustered = (clustee >= 0)
        reduced_dim = dim_embeddings[clustee_name]
            
        print(f"----------{clustee_name}--------------------")

        unique, counts = np.unique(clustee, return_counts=True)
        print(dict(zip(unique, counts)))

        plt.scatter(reduced_dim[~clustered, 0],
                    reduced_dim[~clustered, 1],
                    c=(0.5,0.5,0.5),
                    # s=1,
                    alpha=0.5
                    )
        plt.scatter(reduced_dim[clustered, 0],
                    reduced_dim[clustered, 1],
                    c=clustee[clustered],
                    # s=1,
                    cmap='Spectral')
        plt.show()

# %%
plot()
# Out:
# ----------UMAP_bert1--------------------
# {0: 599, 1: 661, 2: 889, 3: 761}
# ----------UMAP_bert1_norm--------------------
# {0: 662, 1: 705, 2: 669, 3: 874}
# ----------UMAP_bert2--------------------
# {0: 1112, 1: 698, 2: 626, 3: 474}
# ----------UMAP_bert2_norm--------------------
# {0: 594, 1: 1201, 2: 463, 3: 652}
# ----------PCA_bert1--------------------
# {0: 269, 1: 759, 2: 934, 3: 948}
# ----------PCA_bert1_norm--------------------
# {0: 282, 1: 930, 2: 743, 3: 955}
# ----------PCA_bert2--------------------
# {0: 517, 1: 616, 2: 815, 3: 962}
# ----------PCA_bert2_norm--------------------
# {0: 628, 1: 786, 2: 972, 3: 524}
# ----------tSNE_bert1--------------------
# {0: 704, 1: 807, 2: 664, 3: 735}
# ----------tSNE_bert1_norm--------------------
# {0: 915, 1: 739, 2: 764, 3: 492}
# ----------tSNE_bert2--------------------
# {0: 909, 1: 644, 2: 751, 3: 606}
# ----------tSNE_bert2_norm--------------------
# {0: 995, 1: 711, 2: 571, 3: 633}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def tfidfmatrix(data, vectorizer):
    terms = vectorizer.fit_transform(data)
    return pd.DataFrame(terms.toarray(), columns = vectorizer.get_feature_names())

# %%
def cluster_words(clustering_result=clustering_result, top_n = 15, show_cross = False):
    for name, value in clustering_result.items():
        print(f"===================================={name}=============================================")
    
        #creatin new df in order to groupby same clusters
        cluster = value
        docs = pd.DataFrame(df_clean)
        docs["cluster"] = cluster

        labeled_docs = docs.groupby(["cluster"], as_index=False).agg({"tweet": " ".join})

        try : 
            del labeled_docs_try
        except :
            pass
        labeled_docs_try =pd.DataFrame(df_clean)
        labeled_docs_try["labels"] = df.labels
        labeled_docs_try["cluster"] = docs.cluster
        labeled_docs_try.head(50)
        cross = pd.crosstab(labeled_docs_try.labels, labeled_docs_try.cluster)
        if show_cross:
            display(cross)
        else: pass
                
        tfidf_vec = TfidfVectorizer()
        tfidf_mat = tfidfmatrix(labeled_docs.tweet, tfidf_vec)
        
        global most_common
        most_common = pd.DataFrame({n: tfidf_mat.T[col].nlargest(top_n).index.tolist() 
                                for n, col in enumerate(tfidf_mat.T)}).T
        most_common.index = np.unique(cluster)
        display(most_common)

# %%
cluster_words(show_cross = True)
# Out:
# ====================================UMAP_bert1=============================================
# cluster                      0    1    2    3
# labels
# BAD REPUTATION              11   27  161   29
# CHURN                        2    8   21    6
# COVID19                      2   17   16   15
# CUSTOMER_SERVICE_ISSUES     20   60   99   48
# Customer Query              27   27   33   81
# Customer Service Response  366   64  102  121
# DELAY                        3  322  252  139
# ESG                          1    1    4    0
# GOOD REPUTATION             35   15   27   24
# General                    125  118  173  297
# Junk                         4    0    0    0
# Language                     1    0    1    0
#                  0        1         2        3       4         5   \
# 0             thank    hello    please     link    team      send
# 1  bounce_back_loan     week       day  applied   still   account
# 2  bounce_back_loan  nothing  customer  applied     day     worst
# 3  bounce_back_loan  account     thank    hello  please  customer
#
#             6               7            8       9         10    11  \
# 0         call            help    full_name  kindly    detail    dm
# 1  application        customer        thank    back     email  hour
# 2        thank        business      account   hello      call  help
# 3         help  feeder_account  application    back  business  call
#
#             12        13       14
# 0        sorry    assist   number
# 1         time  business     call
# 2  application      time    email
# 3        email    number  applied
# ====================================UMAP_bert1_norm=============================================
# cluster                      0    1    2    3
# labels
# BAD REPUTATION              27   27   12  162
# CHURN                        6    8    3   20
# COVID19                     18    9    7   16
# CUSTOMER_SERVICE_ISSUES     36   69   23   99
# Customer Query              70   34   31   33
# Customer Service Response   74   70  408  101
# DELAY                      116  344    9  247
# ESG                          1    0    1    4
# GOOD REPUTATION             11   15   50   25
# General                    298  127  122  166
# Junk                         3    0    1    0
# Language                     1    0    0    1
#                  0        1         2        3         4        5   \
# 0  bounce_back_loan  account     hello    thank  customer   please
# 1  bounce_back_loan     week       day  applied   account    still
# 2             thank    hello    please     team      link     help
# 3  bounce_back_loan  nothing  customer  applied       day  account
#
#             6               7          8            9       10       11  \
# 0  application  feeder_account       back     business   email  applied
# 1  application        customer       hour        email    call     back
# 2         call            send  full_name        sorry  kindly   detail
# 3        thank        business      hello  application    time    still
#
#       12        13      14
# 0  covid     money    help
# 1  thank  business  please
# 2     dm    assist  number
# 3  worst      call    help
# ====================================UMAP_bert2=============================================
# cluster                      0    1    2    3
# labels
# BAD REPUTATION              82   17   50   79
# CHURN                       17    2    8   10
# COVID19                      2    0   43    5
# CUSTOMER_SERVICE_ISSUES     47   21   27  132
# Customer Query              44   29   63   32
# Customer Service Response   27  507   63   56
# DELAY                      621    7   22   66
# ESG                          0    2    4    0
# GOOD REPUTATION             14   30   30   27
# General                    256   80  312   65
# Junk                         0    2    2    0
# Language                     0    0    1    1
#                  0        1       2        3            4          5   \
# 0  bounce_back_loan  applied    week      day  application    account
# 1             thank    hello  please     link         team  full_name
# 2           account    thank   money    covid        hello        new
# 3          customer     call   thank  account      service       hour
#
#                  6            7         8         9              10      11  \
# 0    feeder_account        email  business  customer        nothing   still
# 1              send         help    kindly      call  thank_writing  assist
# 2              gold  credit_card    please   payment           sony    card
# 3  bounce_back_loan        hello      time       day          worst   still
#
#          12     13      14
# 0   waiting   back    time
# 1     sorry     dm  detail
# 2      help   need    when
# 3  barclays  phone  number
# ====================================UMAP_bert2_norm=============================================
# cluster                      0    1    2    3
# labels
# BAD REPUTATION              13   91   59   65
# CHURN                        2   18   11    6
# COVID19                      2    2   42    4
# CUSTOMER_SERVICE_ISSUES     14   56   29  128
# Customer Query              32   46    4   86
# Customer Service Response  405   33    7  208
# DELAY                        2  650   12   52
# ESG                          2    0    4    0
# GOOD REPUTATION             32   18   36   15
# General                     86  285  255   87
# Junk                         2    0    2    0
# Language                     0    0    2    0
#                  0        1         2     3            4        5          6   \
# 0             thank    hello    please  send         team     link  full_name
# 1  bounce_back_loan  applied       day  week  application  account      email
# 2          customer    covid  barclays  gold         year    thank   business
# 3             hello    thank   account  call       please     help       need
#
#          7               8                 9        10       11           12  \
# 0        dm          detail            kindly     help  message        sorry
# 1  business  feeder_account          customer    still  nothing         back
# 2     worst            sony  bounce_back_loan  service      new         citi
# 3     phone            card          customer   assist     time  credit_card
#
#         13      14
# 0     back  number
# 1  waiting    time
# 2  nigeria   money
# 3   number    back
# ====================================PCA_bert1=============================================
# cluster                      0    1    2    3
# labels
# BAD REPUTATION              21  137   52   18
# CHURN                        2   18   14    3
# COVID19                      1   17   17   15
# CUSTOMER_SERVICE_ISSUES     20   84   87   36
# Customer Query              14   30   52   72
# Customer Service Response   40   72   95  446
# DELAY                       11  215  400   90
# ESG                          0    4    1    1
# GOOD REPUTATION             23   23   20   35
# General                    133  158  195  227
# Junk                         3    0    0    1
# Language                     1    1    0    0
#                  0         1                 2       3        4        5   \
# 0             thank    please  bounce_back_loan    much    hello     help
# 1  bounce_back_loan  customer           nothing    week  applied      day
# 2  bounce_back_loan   account              week   email      day  applied
# 3             thank     hello  bounce_back_loan  please     team     link
#
#             6         7        8         9       10      11        12  \
# 0         know     still      day        dm    need    very  barclays
# 1     business     worst  account     still    call  please      time
# 2  application  customer    thank  business    time    back     hello
# 3         call      help  account      send  kindly    back    number
#
#          13        14
# 0  customer  response
# 1   service     thank
# 2     still   waiting
# 3    assist     email
# ====================================PCA_bert1_norm=============================================
# cluster                      0    1    2    3
# labels
# BAD REPUTATION              21   52  136   19
# CHURN                        3   14   17    3
# COVID19                      1   16   16   17
# CUSTOMER_SERVICE_ISSUES     20   88   82   37
# Customer Query              15   54   28   71
# Customer Service Response   43   92   72  446
# DELAY                       14  402  209   91
# ESG                          0    1    4    1
# GOOD REPUTATION             23   19   23   36
# General                    138  191  155  229
# Junk                         3    0    0    1
# Language                     1    0    1    0
#                  0         1                 2       3                 4   \
# 0             thank    please             hello    much  bounce_back_loan
# 1  bounce_back_loan   account              week   email               day
# 2  bounce_back_loan  customer           nothing    week           applied
# 3             thank     hello  bounce_back_loan  please              team
#
#         5            6         7        8         9         10      11  \
# 0     help          cir     still      day      know  customer      dm
# 1  applied  application  customer    thank  business      time    back
# 2      day     business     worst  account     still      call  please
# 3     link         call      help  account      send    number    back
#
#         12      13     14
# 0     more    need   safe
# 1     call   still  hello
# 2  service    time  thank
# 3   kindly  assist  email
# ====================================PCA_bert2=============================================
# cluster                      0    1    2    3
# labels
# BAD REPUTATION              42   37   78   71
# CHURN                        8   10   16    3
# COVID19                      1    0   48    1
# CUSTOMER_SERVICE_ISSUES      9   49   40  129
# Customer Query              21   23   49   75
# Customer Service Response    5   22   85  541
# DELAY                      260  364   45   47
# ESG                          0    0    6    0
# GOOD REPUTATION              7   29   38   27
# General                    162   82  404   65
# Junk                         0    0    4    0
# Language                     0    0    2    0
#                  0        1            2         3               4        5   \
# 0  bounce_back_loan  account         week  business  feeder_account  applied
# 1  bounce_back_loan  applied  application       day           email     week
# 2             thank  account        covid     money            gold      new
# 3             hello    thank       please      call            team     help
#
#          6        7         8        9        10              11  \
# 0  customer      day     still    money     loan      rishisunak
# 1  customer  account  business  nothing     call  feeder_account
# 2      help   please      sony    hello     time        business
# 3      link     send  customer   number  account          kindly
#
#                  12             13       14
# 0       application  still_waiting    today
# 1              back          still  waiting
# 2  bounce_back_loan         market     more
# 3            assist        service    sorry
# ====================================PCA_bert2_norm=============================================
# cluster                      0    1    2    3
# labels
# BAD REPUTATION              39   76   71   42
# CHURN                        9   16    4    8
# COVID19                      0   48    1    1
# CUSTOMER_SERVICE_ISSUES     52   41  124   10
# Customer Query              25   41   81   21
# Customer Service Response   23   78  547    5
# DELAY                      360   41   45  270
# ESG                          0    6    0    0
# GOOD REPUTATION             31   39   24    7
# General                     89  394   72  158
# Junk                         0    4    0    0
# Language                     0    2    0    0
#                  0        1            2         3        4     5   \
# 0  bounce_back_loan  applied  application       day    email  week
# 1             thank    covid      account      gold    money  help
# 2             hello    thank       please      call     team  help
# 3  bounce_back_loan  account         week  business  applied   day
#
#                6         7         8               9       10          11  \
# 0        customer   account  business  feeder_account    back     nothing
# 1             new      sony    please            time  market    business
# 2            link      send   account        customer  number      kindly
# 3  feeder_account  customer     still           money    loan  rishisunak
#
#                  12           13             14
# 0              call        still        waiting
# 1  bounce_back_loan         year           more
# 2             sorry      service           need
# 3             today  application  still_waiting
# ====================================tSNE_bert1=============================================
# cluster                      0    1    2    3
# labels
# BAD REPUTATION              11  145   46   26
# CHURN                        3   21    5    8
# COVID19                      6   12    8   24
# CUSTOMER_SERVICE_ISSUES     24   92   40   71
# Customer Query              48   31   49   40
# Customer Service Response  438   55  108   52
# DELAY                        7  264  153  292
# ESG                          1    4    0    1
# GOOD REPUTATION             44   25   12   20
# General                    120  157  236  200
# Junk                         0    0    4    0
# Language                     0    1    1    0
#                  0        1         2        3        4            5      6   \
# 0             thank    hello    please     team     link         help   call
# 1  bounce_back_loan  nothing  customer  applied  account          day   week
# 2  bounce_back_loan    thank   account    hello   please     customer  still
# 3  bounce_back_loan  account      week      day  applied  application  email
#
#          7            8       9               10      11     12      13     14
# 0      send       assist  number       full_name  kindly  sorry  detail     dm
# 1  business        still   worst     application   email   call   thank   year
# 2      help  application    call  feeder_account    time   back   money    day
# 3  customer     business   thank            back    time    ago    call  still
# ====================================tSNE_bert1_norm=============================================
# cluster                      0    1    2    3
# labels
# BAD REPUTATION             155   25   16   32
# CHURN                       20    9    4    4
# COVID19                     19    4    3   24
# CUSTOMER_SERVICE_ISSUES    107   59   21   40
# Customer Query              39   62   32   35
# Customer Service Response   55   46  420  132
# DELAY                      316  325   18   57
# ESG                          4    0    1    1
# GOOD REPUTATION             25   13   50   13
# General                    174  195  190  154
# Junk                         0    0    4    0
# Language                     1    0    1    0
#                  0         1        2        3        4            5   \
# 0  bounce_back_loan  customer  nothing  applied  account          day
# 1  bounce_back_loan   account     week  applied      day  application
# 2             thank     hello   please     team     link         help
# 3  bounce_back_loan     hello    thank  account   please     customer
#
#             6         7         8            9                 10        11  \
# 0         week  business     still  application             email      time
# 1        email     still  customer         back             thank  business
# 2         call      send    assist    full_name  bounce_back_loan    kindly
# 3  application      help      call         need            number      more
#
#                12      13      14
# 0            call   worst   thank
# 1  feeder_account  please   hello
# 2              dm   sorry  detail
# 3         working    back    time
# ====================================tSNE_bert2=============================================
# cluster                      0    1    2    3
# labels
# BAD REPUTATION              35   49  102   42
# CHURN                        4    9   14   10
# COVID19                      5    2   42    1
# CUSTOMER_SERVICE_ISSUES     76   12  100   39
# Customer Query              63   28   52   25
# Customer Service Response  567    7   48   31
# DELAY                       18  331   36  331
# ESG                          2    0    4    0
# GOOD REPUTATION             35    7   44   15
# General                    100  197  307  109
# Junk                         0    0    1    3
# Language                     1    0    1    0
#                  0        1            2         3         4               5   \
# 0             thank    hello       please      team      call            link
# 1  bounce_back_loan  account         week  business  customer  feeder_account
# 2          customer  account        thank     money     covid         service
# 3  bounce_back_loan  applied  application       day     email         account
#
#         6        7            8       9      10           11          12  \
# 0     help     send       kindly  number  sorry    full_name        back
# 1  applied  waiting          day    loan  still  application  rishisunak
# 2     time     year  credit_card   worst   help         gold    business
# 3  nothing     week        still    back  heard     business    received
#
#        13             14
# 0  detail  thank_writing
# 1   money           help
# 2    call         please
# 3    time         signed
# ====================================tSNE_bert2_norm=============================================
# cluster                      0    1    2    3
# labels
# BAD REPUTATION              76   14   75   63
# CHURN                       15    1   14    7
# COVID19                      2    3   44    1
# CUSTOMER_SERVICE_ISSUES     40   18   56  113
# Customer Query              39   28    8   93
# Customer Service Response   23  533   14   83
# DELAY                      565    4   26  121
# ESG                          0    2    4    0
# GOOD REPUTATION             13   30   41   17
# General                    220   75  285  133
# Junk                         0    2    2    0
# Language                     0    0    2    0
#                  0                 1         2        3            4   \
# 0  bounce_back_loan           applied       day     week  application
# 1             thank             hello    please     team         link
# 2          customer             covid  barclays  service        thank
# 3           account  bounce_back_loan     thank    hello         call
#
#         5      6         7         8                 9         10  \
# 0  nothing  email  business   account             still  customer
# 1     send   help    detail      call             sorry    kindly
# 2     gold  worst      year  business  bounce_back_loan      sony
# 3   please   back       day      hour          customer      help
#
#                11           12       13       14
# 0  feeder_account         back     time  waiting
# 1   thank_writing       assist  message       dm
# 2           money          new     time     call
# 3           phone  application     need     when
