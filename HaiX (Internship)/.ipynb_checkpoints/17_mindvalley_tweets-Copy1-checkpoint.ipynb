# %%
import re
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
import hdbscan
import nltk
import spacy

import matplotlib.pyplot as plt
from matplotlib.axes._axes import _log as matplotlib_axes_logger
matplotlib_axes_logger.setLevel('ERROR')
import seaborn as sns
sns.set(style='white', rc={'figure.figsize':(10,8)})

np.random.seed(42)
# %config Completer.use_jedi = False
pd.set_option('display.max_columns', 30)
# pd.set_option('display.max_rows', 100)

spaci = spacy.load("en_core_web_sm")

# %%
df = pd.read_csv('mindvalley_tweets.csv')
df.head()
# Out:
#    Unnamed: 0                                              tweet
# 0           0  @Vishen , a CEO that I would REALLY love to he...
# 1           1  The latest episode of the @mindvalley podcast ...
# 2           2  @ImPaulMcKenna @mindvalley A new way of learni...
# 3           3  @moneyman11_c @Vishen @mindvalley What is real...
# 4           4  @manojaryan @Vishen @mindvalley It messed with...

# %%
df.tweet.replace("_" , " ", regex=True, inplace = True)
df.tweet.replace("^" , " ", regex=True, inplace = True)

# %%
df.tweet.head()
# Out:
# 0     @Vishen , a CEO that I would REALLY love to h...
# 1     The latest episode of the @mindvalley podcast...
# 2     @ImPaulMcKenna @mindvalley A new way of learn...
# 3     @moneyman11 c @Vishen @mindvalley What is rea...
# 4     @manojaryan @Vishen @mindvalley It messed wit...
# Name: tweet, dtype: object

# %%
import string
for punc in string.punctuation:
    try:
        df.tweet.replace(f"\{punc}", "", regex=True, inplace = True)
    except:
        pass

# %%
df.tweet[0]
# Out:
# ' Vishen  a CEO that I would REALLY love to hear on your podcast and possibly even have a course on mindvalley is DanPriceSeattle  His philosophy is better aligned to the empathy that Mindvalley inspires Thank you for considering this request httpstcoT7uMGKuv7K'

# %%
junk_words = "tqvm yessssssssssit youuuuuu nan nt citi kashif a very were yet than through via here rishisunak more much getting go going ive dont able when which who year barclays hsbcin amp like an no any since after banking im there out how starlingbank starling one only again over other then am may some do cant about banks would could its even their after has them get got within now all just if what or at had hsbcukbusiness up by into will an was our us so been hsbcuk co om ke ha gone your we can from as but to the hsbc and of you for are have they is my hsbc_uk with it in on this ðÿ be not bank me that"
junk_words_list = junk_words.split(" ")

# %%
def remove_unicode(text):

    try:
        text = text.encode("latin_1").decode("raw_unicode_escape").encode('utf-16', 'surrogatepass').decode('utf-16')
    except:
        text = text

    emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
        "]+", re.UNICODE)

    text = re.sub(emoji_pattern, '', str(text))
    text = ''.join(text.split('\\n')) # to remove uncompiled \n
    text = re.sub('\n', '', text)     # to remove compiled \n

    return text

# %%
def clean_data(text, small_word_lmt=2, extra_words=junk_words_list):
    list_data2=[]
    text = remove_unicode(text)
    sentence=text.lower().split(' ')
    for word in sentence:
        if word == "hi":
            word = word.replace("hi", "hello")
        if not word.startswith('http') \
           and word.isalpha() \
           and len(word)>small_word_lmt \
           and word not in extra_words:
            list_data2.append(word)
    return " ".join(list_data2)
df.tweet = df.tweet.apply(lambda x: clean_data(x))

# %%
df.tweet[0]
# Out:
# 'vishen ceo really love hear podcast possibly course mindvalley danpriceseattle his philosophy better aligned empathy mindvalley inspires thank considering request'

# %%
def word_root(text):
    list_data3=[]
    
    doc = spaci(text)
    for token in doc:
        lemma = token.lemma_
        if lemma != "do":
            list_data3.append(lemma)
        else:pass
    return " ".join(list_data3)
df.tweet = df.tweet.apply(lambda x: word_root(x))

# %%
df.tweet[0]
# Out:
# 'vishen ceo really love hear podcast possibly course mindvalley danpriceseattle his philosophy well align empathy mindvalley inspire thank consider request'

# %%
# adjustment for non-english words

# nltk.download('words')
# eng_words = set(nltk.corpus.words.words())
# df["eng"] = df.tweet.apply(lambda x: " ".join([i for i in nltk.wordpunct_tokenize(x) if i in eng_words]))
# df["noneng"] = df.tweet.apply(lambda x: " ".join([i for i in nltk.wordpunct_tokenize(x) if i not in eng_words]))
# df.noneng.tolist()

# %%
bigram_measures = nltk.collocations.BigramAssocMeasures()
finder = nltk.collocations.BigramCollocationFinder.from_documents([tweet.split() for tweet in df.tweet])
# Filter only those that occur at least 50 times
finder.apply_freq_filter(20)
bigram_scores = finder.score_ngrams(bigram_measures.pmi)

# %%
trigram_measures = nltk.collocations.TrigramAssocMeasures()
finder = nltk.collocations.TrigramCollocationFinder.from_documents([tweet.split() for tweet in df.tweet])
# Filter only those that occur at least 50 times
finder.apply_freq_filter(10)
trigram_scores = finder.score_ngrams(trigram_measures.pmi)

# %%
bigram_pmi = pd.DataFrame(bigram_scores)
bigram_pmi.columns = ['bigram', 'pmi']
bigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)

# %%
trigram_pmi = pd.DataFrame(trigram_scores)
trigram_pmi.columns = ['trigram', 'pmi']
trigram_pmi.sort_values(by='pmi', axis = 0, ascending = False, inplace = True)

# %%
bigrams = [' '.join(x) for x in bigram_pmi.bigram.values if len(x[0]) > 2 or len(x[1]) > 2]
trigrams = [' '.join(x) for x in trigram_pmi.trigram.values if len(x[0]) > 2 or len(x[1]) > 2 and len(x[2]) > 2]

# %%
bigrams
# Out:
# ['vishen mindvalley', 'mindvalley vishen']

# %%
trigrams
# Out:
# ['chainbreakeer garyvee mattdavella',
#  'garyvee mattdavella tomfrankly',
#  'mattdavella tomfrankly robinsharma',
#  'darrenhardy clickfunnel russellbrunson',
#  'jimkwik steven kotler',
#  'mvinsight realjimedward jimkwik',
#  'realjimedward jimkwik steven',
#  'clickfunnel russellbrunson vishen',
#  'tomfrankly robinsharma mindvalley',
#  'mindvalley mvinsight realjimedward',
#  'vishen mindvalley mvinsight',
#  'russellbrunson vishen mindvalley']

# %%
replace_ngrams = {"thank you for":"thank_you_for", "happy birthday":"happy_birthday"}
for key, value in replace_ngrams.items():
    df.tweet.replace(f"\S*{key}\S*" , f"{value} "*3, regex=True, inplace = True)

# %%
# replace_key_words = ['delay', 'wait', 'on_hold', 'any_news', 'awful', 'disappointed', 'give_up', 'regret', 'worse', 'worst', 'unhappy', 'sucksunbelievable', 'frustrated', 'disgusted', 'happy', 'disgrace', 'awesome', 'fantastic', 'well_done', 'great', 'leave', 'bye', 'switch', 'covidenvironment', 'fossil', 'coal', 'fuel', 'climate', 'carbon', 'best', 'wonderfull']
# for key_word in replace_key_words:
#     df.tweet.replace(f"\S*{key_word}\S*" , f"{key_word} "*2, regex=True, inplace = True)

# %%
# df.drop(df[df.tweet.str.contains("tatacrucible")].index, axis=0,inplace=True)

# %%
df_clean = df.tweet
df_clean.shape
# Out:
# (406,)

# %%
df_clean = df_clean.dropna()
df_clean.shape
# Out:
# (406,)

# %%
list_data = df_clean.to_list()
list_data = [str(sent) for sent in list_data]

# %%
from sentence_transformers import SentenceTransformer

# %%
# distilbert-base-nli-mean-tokens
# paraphrase-distilroberta-base-v1

# %%
model=SentenceTransformer('distilbert-base-nli-mean-tokens')
embeddings1 = model.encode(list_data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/13 [00:00<?, ?it/s]

# %%
# embeddings1[embeddings1.argmax()]

# %%
model=SentenceTransformer('paraphrase-distilroberta-base-v1')
embeddings2 = model.encode(list_data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/13 [00:00<?, ?it/s]

# %%
embeddings1_norm = embeddings1 /  np.linalg.norm(embeddings1, axis=1, keepdims=True)
embeddings2_norm = embeddings2 /  np.linalg.norm(embeddings2, axis=1, keepdims=True)

# %%
import umap

# %%
from sklearn.decomposition import PCA 
from sklearn.manifold import TSNE

# %%
UMAP_bert1 = umap.UMAP(n_components=2).fit_transform(embeddings1)
UMAP_bert1_norm = umap.UMAP(n_components=2).fit_transform(embeddings1_norm)

UMAP_bert2 = umap.UMAP(n_components=2).fit_transform(embeddings2)
UMAP_bert2_norm = umap.UMAP(n_components=2).fit_transform(embeddings2_norm)

#n_neighbors=10, min_dist=0.0,

# %%
PCA_bert1 = PCA(n_components=2).fit_transform(embeddings1)
PCA_bert1_norm = PCA(n_components=2).fit_transform(embeddings1_norm)

PCA_bert2 = PCA(n_components=2).fit_transform(embeddings2)
PCA_bert2_norm = PCA(n_components=2).fit_transform(embeddings2_norm)

# %%
tSNE_bert1 = TSNE(n_components=2).fit_transform(embeddings1)
tSNE_bert1_norm = TSNE(n_components=2).fit_transform(embeddings1_norm)

tSNE_bert2 = TSNE(n_components=2).fit_transform(embeddings2)
tSNE_bert2_norm = TSNE(n_components=2).fit_transform(embeddings2_norm)

# %%
from pyclustertend import hopkins
hopkins(UMAP_bert2,UMAP_bert2.shape[0])
# Out:
# 0.16921483901190174

# %%
#inertia

kmeans_per_k = [KMeans(n_clusters=k, random_state=42).fit(UMAP_bert2)
                for k in range(1, 10)]
inertias = [model.inertia_ for model in kmeans_per_k]

plt.plot(range(1, 10), inertias, "bo-")
plt.xlabel("$k$", fontsize=14)
plt.ylabel("Inertia", fontsize=14)
plt.show()

# %%
def cluster_results(Kmeans_clusters=4):
    
    ClusterDict = {}
    dim_embeddings = {"UMAP_bert1" : UMAP_bert1, "UMAP_bert1_norm" : UMAP_bert1_norm, 
                      "UMAP_bert2" : UMAP_bert2, "UMAP_bert2_norm" : UMAP_bert2_norm,
                      "PCA_bert1" : PCA_bert1, "PCA_bert1_norm" : PCA_bert1_norm, 
                      "PCA_bert2" : PCA_bert2, "PCA_bert2_norm" : PCA_bert2_norm,
                      "tSNE_bert1" : tSNE_bert1, "tSNE_bert1_norm" :  tSNE_bert1_norm, 
                      "tSNE_bert2" : tSNE_bert2, "tSNE_bert2_norm" : tSNE_bert2_norm}
    
    for key, val in dim_embeddings.items():
        ClusterDict[key] = KMeans(n_clusters=Kmeans_clusters).fit_predict(val)
        ClusterDict[key+"_hdbscan"] = hdbscan.HDBSCAN(min_samples = 30,
                           min_cluster_size=15,
                           metric = 'euclidean',
                           cluster_selection_epsilon = 0.25,
                           cluster_selection_method = "eom").fit_predict(val)
    return ClusterDict

# %%
clustering_result = cluster_results()

# %%
def plot(cluster = clustering_result):    
    reduced_dims = {"UMAP_bert1" : UMAP_bert1, "UMAP_bert1_norm" : UMAP_bert1_norm, 
                    "UMAP_bert2" : UMAP_bert2, "UMAP_bert2_norm" : UMAP_bert2_norm,
                    "PCA_bert1" : PCA_bert1, "PCA_bert1_norm" : PCA_bert1_norm, 
                    "PCA_bert2" : PCA_bert2, "PCA_bert2_norm" : PCA_bert2_norm,
                    "tSNE_bert1" : tSNE_bert1, "tSNE_bert1_norm" :  tSNE_bert1_norm, 
                    "tSNE_bert2" : tSNE_bert2, "tSNE_bert2_norm" : tSNE_bert2_norm,
                    "UMAP_bert1_hdbscan" : UMAP_bert1, "UMAP_bert1_norm_hdbscan" : UMAP_bert1_norm, 
                    "UMAP_bert2_hdbscan" : UMAP_bert2, "UMAP_bert2_norm_hdbscan" : UMAP_bert2_norm,
                    "PCA_bert1_hdbscan" : PCA_bert1, "PCA_bert1_norm_hdbscan" : PCA_bert1_norm, 
                    "PCA_bert2_hdbscan" : PCA_bert2, "PCA_bert2_norm_hdbscan" : PCA_bert2_norm,
                    "tSNE_bert1_hdbscan" : tSNE_bert1, "tSNE_bert1_norm_hdbscan" :  tSNE_bert1_norm, 
                    "tSNE_bert2_hdbscan" : tSNE_bert2, "tSNE_bert2_norm_hdbscan" : tSNE_bert2_norm}

    for clustee_name, clustee in cluster.items():
        clustered = (clustee >= 0)
        reduced_dim = reduced_dims[clustee_name]
            
        print(f"----------{clustee_name}--------------------")

        unique, counts = np.unique(clustee, return_counts=True)
        print(dict(zip(unique, counts)))

        plt.scatter(reduced_dim[~clustered, 0],
                    reduced_dim[~clustered, 1],
                    c=(0.5,0.5,0.5),
                    # s=1,
                    alpha=0.5
                    )
        plt.scatter(reduced_dim[clustered, 0],
                    reduced_dim[clustered, 1],
                    c=clustee[clustered],
                    # s=1,
                    cmap='Spectral')
        plt.show()

# %%
plot()
# Out:
# ----------UMAP_bert1--------------------
# {0: 98, 1: 104, 2: 115, 3: 89}
# ----------UMAP_bert1_hdbscan--------------------
# {-1: 258, 0: 21, 1: 127}
# ----------UMAP_bert1_norm--------------------
# {0: 75, 1: 138, 2: 89, 3: 104}
# ----------UMAP_bert1_norm_hdbscan--------------------
# {-1: 262, 0: 39, 1: 105}
# ----------UMAP_bert2--------------------
# {0: 44, 1: 122, 2: 131, 3: 109}
# ----------UMAP_bert2_hdbscan--------------------
# {-1: 406}
# ----------UMAP_bert2_norm--------------------
# {0: 103, 1: 71, 2: 119, 3: 113}
# ----------UMAP_bert2_norm_hdbscan--------------------
# {-1: 75, 0: 22, 1: 309}
# ----------PCA_bert1--------------------
# {0: 148, 1: 69, 2: 77, 3: 112}
# ----------PCA_bert1_hdbscan--------------------
# {-1: 406}
# ----------PCA_bert1_norm--------------------
# {0: 112, 1: 77, 2: 71, 3: 146}
# ----------PCA_bert1_norm_hdbscan--------------------
# {-1: 406}
# ----------PCA_bert2--------------------
# {0: 50, 1: 135, 2: 104, 3: 117}
# ----------PCA_bert2_hdbscan--------------------
# {-1: 406}
# ----------PCA_bert2_norm--------------------
# {0: 61, 1: 115, 2: 104, 3: 126}
# ----------PCA_bert2_norm_hdbscan--------------------
# {-1: 406}
# ----------tSNE_bert1--------------------
# {0: 94, 1: 98, 2: 95, 3: 119}
# ----------tSNE_bert1_hdbscan--------------------
# {-1: 244, 0: 30, 1: 132}
# ----------tSNE_bert1_norm--------------------
# {0: 91, 1: 131, 2: 103, 3: 81}
# ----------tSNE_bert1_norm_hdbscan--------------------
# {-1: 406}
# ----------tSNE_bert2--------------------
# {0: 77, 1: 94, 2: 122, 3: 113}
# ----------tSNE_bert2_hdbscan--------------------
# {-1: 406}
# ----------tSNE_bert2_norm--------------------
# {0: 98, 1: 99, 2: 126, 3: 83}
# ----------tSNE_bert2_norm_hdbscan--------------------
# {-1: 196, 0: 17, 1: 193}

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

def tfidfmatrix(data, vectorizer):
    terms = vectorizer.fit_transform(data)
    return pd.DataFrame(terms.toarray(), columns = vectorizer.get_feature_names())

# %%
def cluster_words(clustering_result=clustering_result, top_n = 20):
    for name, value in clustering_result.items():
        print(f"===================================={name}=============================================")
    
        #creatin new df in order to groupby same clusters
        cluster = value
        docs = pd.DataFrame(df_clean)
        docs["cluster"] = cluster

        labeled_docs = docs.groupby(["cluster"], as_index=False).agg({"tweet": " ".join})
                
        tfidf_vec = TfidfVectorizer(max_df=0.9)
        try:
            tfidf_mat = tfidfmatrix(labeled_docs.tweet, tfidf_vec)
        except: pass
        
        global most_common
        most_common = pd.DataFrame({n: tfidf_mat.T[col].nlargest(top_n).index.tolist() 
                                for n, col in enumerate(tfidf_mat.T)}).T
#         most_common.index = np.unique(cluster)
        display(most_common)

# %%
cluster_words()
# Out:
# ====================================UMAP_bert1=============================================
#               0               1               2               3          4   \
# 0           love        complete          always  happy_birthday    awesome
# 1  realjimedward  russellbrunson  danlokofficial     darrenhardy    garyvee
# 2        podcast         youtube         episode             bla      start
# 3     meditation            week        complete             use  australia
#
#             5           6            7              8            9   \
# 0    gratitude   beautiful   meditation       grateful         long
# 1  mattdavella  tomfrankly  clickfunnel  chainbreakeer  robinsharma
# 2       listen        join         love          watch          see
# 3  diymarketer   melbourne     victoria         energy    education
#
#           10              11              12           13           14  \
# 0        big  butfirstcoffee  congratulation         hope  jarvischris
# 1  mvinsight          kotler          steven          fan         know
# 2         ad          minute           never         talk         want
# 3    healing       transform         mermaid  opportunity       shadow
#
#             15             16       17            18           19
# 0          joy       thankful  amazing  conversation     discover
# 1    adventago        youtube    watch         exact  appinventiv
# 2        chart           late   refund        should         stop
# 3  bizapalooza  consciousness     know      powerful      program
# ====================================UMAP_bert1_hdbscan=============================================
#               0               1               2            3        4   \
# 0          thank        complete             day        quest     make
# 1          enjoy            glad          riyazi        there     warm
# 2  realjimedward  russellbrunson  danlokofficial  darrenhardy  jimkwik
#
#                5        6          7       8          9          10       11  \
# 0         youtube     work      start    take      learn        new  podcast
# 1  congratulation   follow  gratitude   acton     anyone  artoflive   avenue
# 2     clickfunnel  podcast     steven  kotler  mvinsight      thank   people
#
#             12          13        14          15          16              17  \
# 0      jimkwik        mind     today       video       watch             bla
# 1  bensonhenry      brewer    chopra  compassion  confidence          desire
# 2  appinventiv  convertkit  dribbble      groove    intercom  jasonrbradwell
#
#           18        19
# 0   grateful      know
# 1   dispense    dondon
# 2  oberloapp  unsplash
# ====================================UMAP_bert1_norm=============================================
#               0               1               2            3               4   \
# 0         minute            week       education        quest            read
# 1       complete      meditation           quest       always  happy_birthday
# 2  realjimedward  russellbrunson  danlokofficial  darrenhardy     clickfunnel
# 3        podcast         episode          listen          bla            talk
#
#           5            6                7            8              9      10  \
# 0    morning        point       searchable         word       practice    new
# 1  gratitude        peace  estheraayorinde      awesome            new   read
# 2    garyvee  mattdavella       tomfrankly    mvinsight  chainbreakeer    fan
# 3    company          see               ad  darrenhardy  realjimedward  chart
#
#           11               12           13              14        15  \
# 0      thing             want         also             app     class
# 1  beautiful  meditationmusic  mindfulness        grateful   healing
# 2     kotler           steven  appinventiv      convertkit  dribbble
# 3        her            check  clickfunnel  danlokofficial    happen
#
#                16        17              18              19
# 0           exact    refund          candle         intense
# 1         insight       big  butfirstcoffee  congratulation
# 2          groove  intercom  jasonrbradwell       oberloapp
# 3  russellbrunson      stop           never           world
# ====================================UMAP_bert1_norm_hdbscan=============================================
#          0         1            2              3            4   \
# 0  complete     quest  darrenhardy  realjimedward  robinsharma
# 1    always  grateful         long          alter         calm
# 2   podcast     watch          bla        episode          his
#
#                5            6               7        8            9        10  \
# 0  russellbrunson  clickfunnel  danlokofficial  garyvee  mattdavella      new
# 1            core         each            glad  perfect       riyazi  session
# 2           start      company              ad    hello          why    exact
#
#            11             12              13             14              15  \
# 0  tomfrankly  chainbreakeer            need           take           think
# 1       there          trust            warm         wilber            zoom
# 2      refund        channel  danlokofficial  realjimedward  russellbrunson
#
#                16      17       18      19
# 0         another  always    start     fan
# 1  butfirstcoffee  divine  forgive      go
# 2          should    stop     talk  across
# ====================================UMAP_bert2=============================================
#             0           1               2          3        4            5   \
# 0  darrenhardy  tomfrankly  danlokofficial  mvinsight  garyvee  mattdavella
# 1        dream       hello  happy_birthday     really     mind  forgiveness
# 2     complete  meditation             day      quest   energy        learn
# 3      podcast      listen         episode        bla     work           ad
#
#           6              7               8            9              10  \
# 0  adventago  realjimedward  russellbrunson  clickfunnel  chainbreakeer
# 1     refund       grateful            work        ahead    diymarketer
# 2     course           week             new         also    masterclass
# 3    journey           talk        business          why         really
#
#             11       12          13       14           15          16  \
# 0  robinsharma      fan      kotler   steven  appinventiv  convertkit
# 1   everywhere  reality  searchable  service      upasana       lucid
# 2         mind      use     fitness  healing     powerful      change
# 3         take    chart        gain   social         join      should
#
#            17         18        19
# 0    dribbble     groove  intercom
# 1         yes    amazing      come
# 2      create  education      take
# 3  experience       find      need
# ====================================UMAP_bert2_hdbscan=============================================
#             0           1               2          3        4            5   \
# 0  darrenhardy  tomfrankly  danlokofficial  mvinsight  garyvee  mattdavella
# 1        dream       hello  happy_birthday     really     mind  forgiveness
# 2     complete  meditation             day      quest   energy        learn
# 3      podcast      listen         episode        bla     work           ad
#
#           6              7               8            9              10  \
# 0  adventago  realjimedward  russellbrunson  clickfunnel  chainbreakeer
# 1     refund       grateful            work        ahead    diymarketer
# 2     course           week             new         also    masterclass
# 3    journey           talk        business          why         really
#
#             11       12          13       14           15          16  \
# 0  robinsharma      fan      kotler   steven  appinventiv  convertkit
# 1   everywhere  reality  searchable  service      upasana       lucid
# 2         mind      use     fitness  healing     powerful      change
# 3         take    chart        gain   social         join      should
#
#            17         18        19
# 0    dribbble     groove  intercom
# 1         yes    amazing      come
# 2      create  education      take
# 3  experience       find      need
# ====================================UMAP_bert2_norm=============================================
#             0            1               2               3            4   \
# 0      podcast      episode          listen             bla        watch
# 1  darrenhardy  clickfunnel      tomfrankly  danlokofficial    mvinsight
# 2        dream     grateful  happy_birthday           hello  forgiveness
# 3     complete      jimkwik           quest      meditation         body
#
#               5               6           7           8        9   \
# 0             ad           learn    business       check  journey
# 1  realjimedward  russellbrunson         fan     garyvee  jimkwik
# 2         refund           ahead  everywhere  politician  reality
# 3           week           brain      energy     healing   course
#
#             10         11         12               13             14  \
# 0       course  education      chart              her      interview
# 1  mattdavella     kotler  adventago      robinsharma  chainbreakeer
# 2   searchable    service    upasana            lucid        another
# 3         find   exercise       flow  meditationmusic          train
#
#          15           16           17          18             19
# 0  lakhiani         late         join        help  impaulmckenna
# 1    steven  appinventiv  bizapalooza  convertkit       dribbble
# 2      come        exact    gratitude      leader        support
# 3    minute      program          way      create       powerful
# ====================================UMAP_bert2_norm_hdbscan=============================================
#             0            1            2         3            4          5   \
# 0  darrenhardy   tomfrankly  robinsharma   garyvee  mattdavella      quest
# 1  clickfunnel  appinventiv   convertkit  dribbble       groove  headspace
# 2      podcast       really          day    course       create      start
#
#               6               7          8            9            10  \
# 0  chainbreakeer        complete  mvinsight  clickfunnel          fan
# 1       intercom  jasonrbradwell  oberloapp     unsplash    becurefit
# 2           mind            take     people         help  masterclass
#
#             11         12               13            14           15  \
# 0   meditation       read        adventago          post  bizapalooza
# 1  invisionapp  mailchimp  mindorksnextgen  sproutsocial    adventago
# 2        video  education             want       episode       growth
#
#                 16              17            18          19
# 0  bizapaloozachat          darren   diymarketer       tweet
# 1       artofthemp  brightmindsbio  dreamscholar  howtolucid
# 2             know             new         watch     program
# ====================================PCA_bert1=============================================
#             0               1            2          3               4   \
# 0      podcast         youtube  darrenhardy      watch         episode
# 1       always  congratulation      awesome  gratitude         upasana
# 2  diymarketer            mind        prove     shadow     bizapalooza
# 3        great            live       people   grateful  happy_birthday
#
#             5       6                7               8                9   \
# 0       listen     bla    realjimedward  russellbrunson            video
# 1      anubhav    glad  justinnfurtadoo          latifa              mak
# 2         body    need      robinsharma            week  bizapaloozachat
# 3  robinsharma  always          garyvee            mind    realjimedward
#
#                10      11      12         13       14       15  \
# 0  danlokofficial   start  steven        why   happen     join
# 1         rishabh  riyazi    warm     energy    happy     true
# 2         believe     hee     les     nobody   seldom      sir
# 3  russellbrunson   share    also  education  youtube  awesome
#
#                16          17         18      19
# 0     clickfunnel       learn        fan   never
# 1             yes       agree  beautiful     big
# 2      subjective       sugar     urgent  energy
# 3  danlokofficial  experience       know   learn
# ====================================PCA_bert1_hdbscan=============================================
#             0               1            2          3               4   \
# 0      podcast         youtube  darrenhardy      watch         episode
# 1       always  congratulation      awesome  gratitude         upasana
# 2  diymarketer            mind        prove     shadow     bizapalooza
# 3        great            live       people   grateful  happy_birthday
#
#             5       6                7               8                9   \
# 0       listen     bla    realjimedward  russellbrunson            video
# 1      anubhav    glad  justinnfurtadoo          latifa              mak
# 2         body    need      robinsharma            week  bizapaloozachat
# 3  robinsharma  always          garyvee            mind    realjimedward
#
#                10      11      12         13       14       15  \
# 0  danlokofficial   start  steven        why   happen     join
# 1         rishabh  riyazi    warm     energy    happy     true
# 2         believe     hee     les     nobody   seldom      sir
# 3  russellbrunson   share    also  education  youtube  awesome
#
#                16          17         18      19
# 0     clickfunnel       learn        fan   never
# 1             yes       agree  beautiful     big
# 2      subjective       sugar     urgent  energy
# 3  danlokofficial  experience       know   learn
# ====================================PCA_bert1_norm=============================================
#             0               1            2               3            4   \
# 0        great          people     grateful  happy_birthday  robinsharma
# 1  diymarketer            mind        prove          shadow  bizapalooza
# 2       always  congratulation      awesome       gratitude      upasana
# 3      podcast         youtube  darrenhardy           watch      episode
#
#         5            6                7                8        9   \
# 0   always      garyvee             mind            share     also
# 1     body  robinsharma             week  bizapaloozachat  believe
# 2  anubhav         glad  justinnfurtadoo           latifa      mak
# 3   listen          bla    realjimedward   russellbrunson    video
#
#                10       11       12          13             14     15  \
# 0       education  youtube  awesome  experience           know  learn
# 1             hee      les   nobody   philstupf         seldom    sir
# 2      perception  rishabh   riyazi        warm  consciousness   feel
# 3  danlokofficial    start   steven         why         happen   join
#
#             16             17              18              19
# 0  mattdavella  realjimedward  russellbrunson           thing
# 1        sugar         urgent     clickfunnel  danlokofficial
# 2        happy           true             yes       beautiful
# 3  clickfunnel          learn             fan           never
# ====================================PCA_bert1_norm_hdbscan=============================================
#             0               1            2               3            4   \
# 0        great          people     grateful  happy_birthday  robinsharma
# 1  diymarketer            mind        prove          shadow  bizapalooza
# 2       always  congratulation      awesome       gratitude      upasana
# 3      podcast         youtube  darrenhardy           watch      episode
#
#         5            6                7                8        9   \
# 0   always      garyvee             mind            share     also
# 1     body  robinsharma             week  bizapaloozachat  believe
# 2  anubhav         glad  justinnfurtadoo           latifa      mak
# 3   listen          bla    realjimedward   russellbrunson    video
#
#                10       11       12          13             14     15  \
# 0       education  youtube  awesome  experience           know  learn
# 1             hee      les   nobody   philstupf         seldom    sir
# 2      perception  rishabh   riyazi        warm  consciousness   feel
# 3  danlokofficial    start   steven         why         happen   join
#
#             16             17              18              19
# 0  mattdavella  realjimedward  russellbrunson           thing
# 1        sugar         urgent     clickfunnel  danlokofficial
# 2        happy           true             yes       beautiful
# 3  clickfunnel          learn             fan           never
# ====================================PCA_bert2=============================================
#             0               1              2               3          4   \
# 0  darrenhardy  danlokofficial  realjimedward  russellbrunson  mvinsight
# 1     complete           quest     meditation             new      learn
# 2       really            mind             ad            work   grateful
# 3          bla         podcast           work            need    episode
#
#                5            6            7           8          9   \
# 0     clickfunnel      garyvee  mattdavella  tomfrankly  adventago
# 1         podcast  masterclass        dream        live       take
# 2          shadow         feel          hey  meditation     across
# 3  happy_birthday          see          use        take      chart
#
#             10       11        12             13           14          15  \
# 0       kotler   steven       fan  chainbreakeer  appinventiv  convertkit
# 1         week     work   episode        program         want      create
# 2  masterclass  reality  remember     searchable         true      valley
# 3         gain   social      call           help         live      really
#
#            16       17        18              19
# 0    dribbble   groove  intercom  jasonrbradwell
# 1     fitness   refund    access            body
# 2  absolutely  anubhav    arabic           cupey
# 3        talk    ahead   improve         startup
# ====================================PCA_bert2_hdbscan=============================================
#             0               1              2               3          4   \
# 0  darrenhardy  danlokofficial  realjimedward  russellbrunson  mvinsight
# 1     complete           quest     meditation             new      learn
# 2       really            mind             ad            work   grateful
# 3          bla         podcast           work            need    episode
#
#                5            6            7           8          9   \
# 0     clickfunnel      garyvee  mattdavella  tomfrankly  adventago
# 1         podcast  masterclass        dream        live       take
# 2          shadow         feel          hey  meditation     across
# 3  happy_birthday          see          use        take      chart
#
#             10       11        12             13           14          15  \
# 0       kotler   steven       fan  chainbreakeer  appinventiv  convertkit
# 1         week     work   episode        program         want      create
# 2  masterclass  reality  remember     searchable         true      valley
# 3         gain   social      call           help         live      really
#
#            16       17        18              19
# 0    dribbble   groove  intercom  jasonrbradwell
# 1     fitness   refund    access            body
# 2  absolutely  anubhav    arabic           cupey
# 3        talk    ahead   improve         startup
# ====================================PCA_bert2_norm=============================================
#             0                1               2          3            4   \
# 0  darrenhardy       tomfrankly  danlokofficial  mvinsight  clickfunnel
# 1        video           energy           world       mind       really
# 2        quest         complete            body    episode       listen
# 3          bla  estheraayorinde  happy_birthday    episode         talk
#
#               5               6       7         8            9          10  \
# 0  realjimedward  russellbrunson     fan   garyvee  mattdavella  adventago
# 1         valley             yes  create  complete          hey       feel
# 2           time            want  refund      help     practice     course
# 3           need          really   share      help        world     always
#
#               11           12      13        14           15          16  \
# 0  chainbreakeer  robinsharma  kotler    steven  appinventiv  convertkit
# 1           true       become  shadow     dream         hear       lucid
# 2        journey  masterclass    week  exercise        focus       level
# 3         course        power     see     video       across       ahead
#
#             17       18        19
# 0     dribbble   groove  intercom
# 1  masterclass    super        ad
# 2       master  morning   process
# 3       system   vision      word
# ====================================PCA_bert2_norm_hdbscan=============================================
#             0                1               2          3            4   \
# 0  darrenhardy       tomfrankly  danlokofficial  mvinsight  clickfunnel
# 1        video           energy           world       mind       really
# 2        quest         complete            body    episode       listen
# 3          bla  estheraayorinde  happy_birthday    episode         talk
#
#               5               6       7         8            9          10  \
# 0  realjimedward  russellbrunson     fan   garyvee  mattdavella  adventago
# 1         valley             yes  create  complete          hey       feel
# 2           time            want  refund      help     practice     course
# 3           need          really   share      help        world     always
#
#               11           12      13        14           15          16  \
# 0  chainbreakeer  robinsharma  kotler    steven  appinventiv  convertkit
# 1           true       become  shadow     dream         hear       lucid
# 2        journey  masterclass    week  exercise        focus       level
# 3         course        power     see     video       across       ahead
#
#             17       18        19
# 0     dribbble   groove  intercom
# 1  masterclass    super        ad
# 2       master  morning   process
# 3       system   vision      word
# ====================================tSNE_bert1=============================================
#             0        1            2               3               4   \
# 0  darrenhardy  youtube      podcast   realjimedward  danlokofficial
# 1    headspace  garyvee  appinventiv      convertkit        dribbble
# 2      podcast    start    education         company           first
# 3   meditation   always        quest  happy_birthday           dream
#
#                5          6               7                8         9   \
# 0  russellbrunson        bla     clickfunnel              fan    steven
# 1          groove   intercom  jasonrbradwell        oberloapp  unsplash
# 2          minute      today           exact          episode   youtube
# 3            find  gratitude       beautiful  meditationmusic  grateful
#
#             10               11          12           13          14  \
# 0      episode           kotler   mvinsight           ad       never
# 1  mattdavella       tomfrankly   becurefit  invisionapp   mailchimp
# 2       launch          morning       point       reward  searchable
# 3  mindfulness  estheraayorinde  experience          way       sleep
#
#                 15              16              17             18         19
# 0        adventago          listen             see          chart     happen
# 1  mindorksnextgen    sproutsocial            week  chainbreakeer  australia
# 2             word        business           daily       practice       week
# 3              big  butfirstcoffee  congratulation         divine         go
# ====================================tSNE_bert1_hdbscan=============================================
#           0            1          2              3               4   \
# 0   complete          day      quest           work            make
# 1  gratitude      anubhav       glad         latifa             mak
# 2    podcast  darrenhardy  mvinsight  realjimedward  russellbrunson
#
#                5        6          7                8            9        10  \
# 0            read     mind        new          program        video  jimkwik
# 1         rishabh   riyazi  beautiful  estheraayorinde       writer     amen
# 2  danlokofficial  jimkwik     steven              fan  clickfunnel   kotler
#
#         11          12       13         14         15             16  \
# 0    learn        need   people      watch    youtube            bla
# 1   bridge  confidence  correct  cultivate     denise  denisebuchman
# 2  episode      listen  youtube       make  headspace      adventago
#
#             17           18          19
# 0        never          say        long
# 1       desire        faith  generosity
# 2  mattdavella  robinsharma       start
# ====================================tSNE_bert1_norm=============================================
#            0               1              2               3               4   \
# 0       quest     diymarketer            big     jarvischris        positive
# 1     podcast     darrenhardy  realjimedward  danlokofficial  russellbrunson
# 2  meditation  happy_birthday         always        grateful         awesome
# 3     youtube          minute          watch            week           quest
#
#             5         6            7          8          9            10  \
# 0       shadow    always  bizapalooza     energy       turn          yes
# 1  clickfunnel       see          bla      never        fan  mattdavella
# 2    gratitude  powerful        enjoy       kind      train  mindfulness
# 3        exact        ad       people  australia  melbourne   searchable
#
#                 11        12               13           14             15  \
# 0  bizapaloozachat   believe  justinnfurtadoo          les    possibility
# 1       tomfrankly   episode           kotler    mvinsight        garyvee
# 2             also     today             help       people  realjimedward
# 3         tomorrow  victoria          channel  mattdavella            use
#
#                16           17          18          19
# 0             sir        sugar       lucid        rise
# 1          listen  appinventiv  convertkit    dribbble
# 2  russellbrunson      healing       teach      badass
# 3   chainbreakeer        first  motivation  tomfrankly
# ====================================tSNE_bert1_norm_hdbscan=============================================
#            0               1              2               3               4   \
# 0       quest     diymarketer            big     jarvischris        positive
# 1     podcast     darrenhardy  realjimedward  danlokofficial  russellbrunson
# 2  meditation  happy_birthday         always        grateful         awesome
# 3     youtube          minute          watch            week           quest
#
#             5         6            7          8          9            10  \
# 0       shadow    always  bizapalooza     energy       turn          yes
# 1  clickfunnel       see          bla      never        fan  mattdavella
# 2    gratitude  powerful        enjoy       kind      train  mindfulness
# 3        exact        ad       people  australia  melbourne   searchable
#
#                 11        12               13           14             15  \
# 0  bizapaloozachat   believe  justinnfurtadoo          les    possibility
# 1       tomfrankly   episode           kotler    mvinsight        garyvee
# 2             also     today             help       people  realjimedward
# 3         tomorrow  victoria          channel  mattdavella            use
#
#                16           17          18          19
# 0             sir        sugar       lucid        rise
# 1          listen  appinventiv  convertkit    dribbble
# 2  russellbrunson      healing       teach      badass
# 3   chainbreakeer        first  motivation  tomfrankly
# ====================================tSNE_bert2=============================================
#             0              1           2               3          4   \
# 0  darrenhardy    clickfunnel  tomfrankly  danlokofficial  mvinsight
# 1          bla             ad       never           exact     refund
# 2   meditation  consciousness    complete           dream        way
# 3      podcast         listen       quest         episode   complete
#
#                5                6           7            8             9   \
# 0         garyvee      mattdavella      kotler       steven     adventago
# 1          access      diymarketer  searchable       valley       message
# 2     forgiveness  meditationmusic     reality  mindfulness           yes
# 3  happy_birthday             find        time         talk  conversation
#
#             10             11        12           13          14        15  \
# 0  robinsharma  chainbreakeer       fan  appinventiv  convertkit  dribbble
# 1        still          today   channel   experience        hear      help
# 2       energy       grateful  practice        today     fitness      give
# 3      discuss          happy     enjoy         flow      reward  strategy
#
#         16        17              18          19
# 0   groove  intercom  jasonrbradwell   oberloapp
# 1  program      time             app  meditation
# 2   leader      past        powerful       prove
# 3   steven    minute            call  experience
# ====================================tSNE_bert2_hdbscan=============================================
#             0              1           2               3          4   \
# 0  darrenhardy    clickfunnel  tomfrankly  danlokofficial  mvinsight
# 1          bla             ad       never           exact     refund
# 2   meditation  consciousness    complete           dream        way
# 3      podcast         listen       quest         episode   complete
#
#                5                6           7            8             9   \
# 0         garyvee      mattdavella      kotler       steven     adventago
# 1          access      diymarketer  searchable       valley       message
# 2     forgiveness  meditationmusic     reality  mindfulness           yes
# 3  happy_birthday             find        time         talk  conversation
#
#             10             11        12           13          14        15  \
# 0  robinsharma  chainbreakeer       fan  appinventiv  convertkit  dribbble
# 1        still          today   channel   experience        hear      help
# 2       energy       grateful  practice        today     fitness      give
# 3      discuss          happy     enjoy         flow      reward  strategy
#
#         16        17              18          19
# 0   groove  intercom  jasonrbradwell   oberloapp
# 1  program      time             app  meditation
# 2   leader      past        powerful       prove
# 3   steven    minute            call  experience
# ====================================tSNE_bert2_norm=============================================
#             0            1           2               3            4   \
# 0  darrenhardy  clickfunnel  tomfrankly  danlokofficial  robinsharma
# 1     complete        quest     jimkwik           learn  masterclass
# 2      podcast      youtube        time             bla        watch
# 3       always   everywhere     morning      searchable        hello
#
#           5              6               7          8               9   \
# 0  mvinsight  realjimedward  russellbrunson        fan         garyvee
# 1      dream        fitness           lucid     course            week
# 2         ad        episode          listen  education         journey
# 3     minute          exact     forgiveness   advanced  butfirstcoffee
#
#                 10              11       12         13             14  \
# 0      mattdavella          kotler  podcast  adventago  chainbreakeer
# 1  meditationmusic        powerful      new        use           body
# 2          company  happy_birthday      new        hey         create
# 3           candle        delegate  forgive   thankful    videosearch
#
#         15        16           17           18          19
# 0  jimkwik    steven  appinventiv  bizapalooza  convertkit
# 1    brain    create       energy      program       class
# 2   follow  lakhiani       refund       social      access
# 3   myself     quest        thing     actually     develop
# ====================================tSNE_bert2_norm_hdbscan=============================================
#            0            1              2               3            4   \
# 0     garyvee     complete     tomfrankly     darrenhardy         love
# 1   adventago  clickfunnel  realjimedward  russellbrunson  appinventiv
# 2  meditation         mind           work          create         love
#
#               5               6               7       8            9   \
# 0  realjimedward  russellbrunson  danlokofficial   quest  mattdavella
# 1     convertkit  danlokofficial        dribbble  groove     intercom
# 2         really            take             bla   dream         find
#
#                10           11         12         13         14            15  \
# 0   chainbreakeer  clickfunnel     kotler       read       work        always
# 1  jasonrbradwell       kotler  mailchimp  mvinsight  oberloapp  sproutsocial
# 2          people        start      watch         ad        hey   masterclass
#
#          16          17              18            19
# 0       fan   mvinsight             why        course
# 1  unsplash  artofthemp  brightmindsbio  dreamscholar
# 2       new        time             use         world
