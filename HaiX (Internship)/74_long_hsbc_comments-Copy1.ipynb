# %% [markdown]
# # 1. Imports and reading data

# %%
# %%time
import time
import re
import pandas as pd
import numpy as np
import umap
import string
import hdbscan
import spacy
import gensim
import sklearn

from sklearn.cluster import KMeans
from nltk.corpus import stopwords
from sentence_transformers import SentenceTransformer
from keybert import KeyBERT

nlp = spacy.load('en_core_web_sm', disable = ['parser', 'ner'])
stop = stopwords.words('english')
model=SentenceTransformer('xlm-r-distilroberta-base-paraphrase-v1')
kw_extractor = KeyBERT(model=model)

# %config Completer.use_jedi = False
# Out:
# Wall time: 15.3 s

# %%
# xlm-r-distilroberta-base-paraphrase-v1
# distilbert-base-nli-mean-tokens

# %%
start = time.time()

# %%
df = pd.read_csv('hsbc_comments.csv')
df.rename(columns={"message":"comments"},inplace=True)

# %% [markdown]
# # 2. Preprocessing

# %%
#This takes each sentence as inputs and returns list of clean tokens for that sentence
def TextCleaner(doc):
    doc = re.sub("[,.']", "", str(doc))
    doc = [token for token in doc.lower().split(' ') if len(re.sub("[a-z]", "", token)) <= 0]
    doc = nlp(" ".join(doc))
    taglist = ['RB','RBR', 'RBS','JJR','JJ','JJS','NN','NNS','VB','VBG','VBP','VBN']
    poslist = ['ADJ','ADV','NOUN','VERB']
    doc = [token.lemma_ for token in doc if token.tag_ in taglist and token.pos_ in poslist]
    doc = [token for token in doc if not token in stop and len(token)>2 and len(token)<15]
    return doc

# %%
# This function converts a list of clean documents to trigrams 
def TextNGram(doc,ngrams = 3):
    bigram = gensim.models.Phrases(doc , min_count=7, threshold=70) # higher threshold fewer phrases.
    bigram_mod = gensim.models.phrases.Phraser(bigram)
    if ngrams == 2:
        doc = [bigram_mod[sent] for sent in doc]
        return doc
    elif ngrams == 3:
        trigram = gensim.models.Phrases(bigram[doc], threshold=5)
        trigram_mod = gensim.models.phrases.Phraser(trigram)
        doc = [trigram_mod[bigram_mod[sent]] for sent in doc]
        return doc
    else:
        return doc

# %%
# %%time
#First 
df['Processed'] = [TextCleaner(f) for f in df['comments']]
#Second
df['Processed_ngram'] = TextNGram(df['Processed'])
# Out:
# Wall time: 6.4 s

# %%
print(df['Processed_ngram'].tolist())
# Out:
# [['like', 'say', 'massive', 'thank', 'hsbc', 'telephone', 'use', 'card', 'help', 'thorough', 'process', 'stop', 'friendly', 'always', 'bank', 'hsbc'], ['run_try', 'get_basic', 'banking', 'service_right', 'first_try', 'get', 'money_transfer', 'credit_card', 'account', 'back_current', 'account_refund', 'british_january', 'initially_tell', 'call_christian', 'take_day', 'still_sign', 'use_web', 'chat_service', 'today', 'tell_today', 'tuesday_january', 'call_askshith', 'take_working', 'day_january', 'hour', 'get', 'information_today', 'keep_get', 'run_around', 'people_overseas', 'apologise_patronising', 'way', 'tell', 'ever_apologise', 'ever_also', 'try_blame', 'somewhere_never', 'fault_restore', 'confidence_bank'], ['send', 'neccesary', 'number', 'use', 'online', 'service', 'wait', 'week', 'help'], ['past', 'hour', 'wait', 'time', 'service'], ['melanie', 'humberstone'], ['brilliant'], ['absolutely', 'fume', 'sit', 'hold', 'almost', 'hour', 'telephone', 'line', 'able', 'change', 'withdrawal', 'limit', 'register', 'complaint', 'withdraw', 'money', 'forthwith'], ['love_donate', 'year', 'unfortunately', 'hsbc_freeze', 'business_account', 'letter_say', 'close_account', 'last_month', 'send_cheque', 'balance_unfortunately', 'staff_keep', 'word_know', 'pointless_post', 'say_certainly_sweetness', 'light_try', 'make'], ['possible', 'answer', 'telephone', 'less', 'actually', 'help', 'business', 'create', 'wealth'], ['card', 'take', 'long', 'opne'], ['bad', 'banking', 'experience', 'life', 'year', 'banking', 'close_account', 'monday', 'way', 'treat', 'disgusting', 'transfer_money', 'urgently', 'make', 'wait', 'branch', 'monday', 'make', 'branch', 'middle', 'pandemic', 'diligent', 'enough', 'check', 'online', 'disappointed', 'service', 'issue', 'take', 'money', 'take', 'back', 'war', 'people', 'need', 'avoid', 'bank', 'post', 'social', 'medium', 'platform', 'disgusting'], ['complaint', 'bad_team', 'time', 'hsbc_egypt_regret', 'deal_premier', 'customer_suffer', 'month_issue', 'debit_card_load', 'problem_error', 'due_chaotic_standard', 'management_cover_mistake', 'instead_try', 'fix_unable', 'simple_transaction', 'transfer_account', 'egypt_simply', 'team_loser', 'great_failure_compare', 'hsbc', 'hsbc_qatar'], ['call', 'evening', 'suggestion', 'home', 'bad_service', 'ever', 'receive'], ['notice'], ['good', 'try_make', 'online', 'payment', 'receive', 'time', 'access', 'code', 'mobile', 'hsbc', 'need', 'recognise', 'problem', 'offer', 'option', 'receive', 'code', 'landline', 'bank', 'offer'], ['deal', 'money', 'steal', 'personal', 'relative', 'fob', 'ask', 'help', 'take', 'personal', 'account', 'transaction', 'spend_hour', 'phone', 'pleading', 'explanation', 'help', 'security', 'mobile_banking', 'system', 'fail', 'tell', 'accept', 'money', 'hsbc', 'fault'], ['begin', 'believe', 'want', 'new', 'business', 'apply', 'account', 'partner', 'drip', 'feed', 'request', 'information', 'provide', 'find', 'active', 'hold', 'long', 'music', 'overseas', 'ring', 'tone', 'hour', 'min', 'far', 'local_branch', 'staff', 'experienced', 'competent', 'personnel', 'currently', 'twiddle', 'thumb', 'open_account', 'branch', 'use', 'online', 'system', 'clearly', 'break', 'account', 'need', 'work', 'freelancer', 'never', 'difficult', 'painful'], ['glad_introduce_genuine', 'company_earn_cool', 'cash_stay_home_benefit', 'company_share_goodnew', 'direct_tooclick_link', 'contact_shawn_mende', 'start_earn'], ['really', 'bank', 'scam', 'money', 'take', 'account', 'numerous', 'time', 'last', 'year', 'unauthorised', 'get', 'tell', 'refund', 'back', 'account', 'ridiculous', 'joke', 'time', 'cancel', 'block', 'card', 'guy', 'year', 'even', 'return', 'money', 'take', 'ashamed'], ['need', 'sort', 'bounce_loan', 'cycle', 'event', 'june', 'still', 'good_enough', 'long', 'stand', 'business', 'customer'], ['letter', 'explain', 'new', 'overdraft', 'procedure', 'make', 'charge', 'variable', 'overdraft', 'limit', 'get', 'charge', 'case', 'ill', 'agree', 'overdraft', 'limit', 'able', 'charge'] ...

# %%
data = pd.Series(df['Processed_ngram'].apply(lambda x: " ".join(x) if len(x) > 4 else np.nan))

# %%
data.dropna(axis=0, inplace=True)
data.reset_index(drop=True,inplace=True)

# %%
list_data = data.unique().tolist()

# %% [markdown]
# # 3. Model, Dimension Reduction and Saving Model

# %% [markdown]
# ##     a. BERT Model

# %%
# %%time
embeddings = model.encode(list_data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/22 [00:00<?, ?it/s]
# Wall time: 56 s

# %% [markdown]
# ## b. UMAP Dimension Reduction

# %%
embedding_norm = sklearn.preprocessing.normalize(embeddings, norm='l2')

# %%
# %%time
best_model = umap.UMAP(n_components=5,min_dist=0.0).fit_transform(embedding_norm)

# #n_neighbors=10, min_dist=0.0,
# Out:
# Wall time: 10.8 s

# %% [markdown]
# # 4. Clustering and Reducing Clusters with Cosine-Similarity

# %% [markdown]
# ## a. HDBSCAN Clustering

# %%
# %%time
cluster = KMeans(n_clusters=4, init="k-means++").fit_predict(best_model)
# Out:
# Wall time: 75 ms

# %%
# %%time
docs = pd.DataFrame(list_data,columns=["comments"])
docs["cluster"] = cluster
labeled_docs = docs.groupby(["cluster"], as_index=False).agg({"comments": " ".join})
array_text = labeled_docs.comments.tolist()
# Out:
# Wall time: 13 ms

# %%
# %%time
for j in range(len(array_text)):
    keywords = kw_extractor.extract_keywords(array_text[j], top_n=10)
    print(f'\033[1m   Cluster {j+1}: \033[0m')
    print([word for word, degree in keywords])
# Out:
#    Cluster 1:
# ['bad_service', 'transfer_account', 'bankrupt', 'bank', 'problem_error', 'transfer_money', 'customer_service', 'business_account', 'bad_team', 'banking']
#    Cluster 2:
# ['try_get', 'run_try', 'chat_service', 'call_christian', 'transfer_account', 'customer_service', 'try', 'call_barclaycard', 'telephone_banking', 'account_refund']
#    Cluster 3:
# ['staff_pensioner', 'pensioner', 'fraud', 'pension', 'state_pension', 'brazil', 'trustee', 'financial', 'clawbank', 'claw_back']
#    Cluster 4:
# ['account_refund', 'saving_account', 'fraud', 'secure_key', 'safeguard', 'telephone_banking', 'bank', 'letter_say', 'safeguarding', 'credit_card']
# Wall time: 45.6 s

# %%
end = time.time()
print(end - start)
# Out:
# 213.5800621509552
